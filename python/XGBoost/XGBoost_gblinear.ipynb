# %% [markdown]
# # XGBoost with gblinear Booster

# %%
# Import libraries
import numpy as np
import pandas as pd
import pickle
import time
import xgboost as xgb
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 16})

# Metrics
from sklearn.metrics import auc, roc_curve, roc_auc_score, precision_score, accuracy_score, recall_score, f1_score, precision_recall_curve, confusion_matrix

# %% [markdown]
# # Load Data

# %%
# Load pickled data
df = pd.read_pickle("data/yelp_df_final.pkl")

# Split data
train_df = df[df["dataset"] == "train"]
valid_df = df[df["dataset"] == "val"].reset_index(drop = True)
test_df  = df[df["dataset"] == "test"].reset_index(drop = True)

# %%
# Parameters excluded from predictions
exclude = ["review_id", 
           "business_id", 
           "user_id", 
           "label", 
           "date", 
           "categories", 
           "is_open",
           "postal_code", 
           "dataset"]

# Predictors
predictors = list(train_df.columns)
for col in exclude:   
    predictors.remove(col)

# Label
outcome = "label"

# %%
# Train features and labels
X_train = np.array(train_df[predictors])
y_train = np.array(train_df[outcome])

# Validation features and labels
X_valid = np.array(valid_df[predictors])
y_valid = np.array(valid_df[outcome])

# Test features and labels
X_test  = np.array(test_df[predictors])
y_test  = np.array(test_df[outcome])

# %%
# Save XGBoost data types 
dtrain = xgb.DMatrix(X_train, label = y_train)
dvalid = xgb.DMatrix(X_valid, label = y_valid)
dtest  = xgb.DMatrix(X_test,  label = y_test)

# %% [markdown]
# # Set Parameters

# %%
# Hyperparameters for model
param = {'max_depth': 4,
         'eta': 1.0,
         'min_child_weight': 1}

# Base estimator
param['booster'] = 'gblinear'

# Learning task and corresponding learning objective
param['objective'] = 'binary:logistic'

# Evaluation metrics for validation data 
# (wrong cases) / (all cases)
param['eval_metric'] = 'error' 

# Specify validation set to watch performance
evallist = [(dvalid, 'eval'), (dtrain, 'train')]

# Number of rounds for boosting
num_round = 200

# Validation error needs to decrease at least every early_stopping_rounds 
early_stopping_rounds = 2

# %% [markdown]
# # Training

# %%
# Start timer 
start_time = time.time()

# Train model
bst = xgb.train(params = param, 
                dtrain = dtrain, 
                num_boost_round = num_round, 
                evals = evallist,
                early_stopping_rounds = early_stopping_rounds)

# End timer
end_time = time.time()
print("Time for training: {:.2f} seconds".format(end_time - start_time))
print("Best iteration         {}".format(bst.best_iteration))
# Out:
# [0]	eval-error:0.406649	train-error:0.368352
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 2 rounds.
# [1]	eval-error:0.393413	train-error:0.358211
# [2]	eval-error:0.374709	train-error:0.345929
# [3]	eval-error:0.357409	train-error:0.334686
# [4]	eval-error:0.343382	train-error:0.325615
# [5]	eval-error:0.331989	train-error:0.318389
# [6]	eval-error:0.323565	train-error:0.312615
# [7]	eval-error:0.31669	train-error:0.307776
# [8]	eval-error:0.310962	train-error:0.303649
# [9]	eval-error:0.305639	train-error:0.300115
# [10]	eval-error:0.301127	train-error:0.297097
# [11]	eval-error:0.297114	train-error:0.29437
# [12]	eval-error:0.293747	train-error:0.291936
# [13]	eval-error:0.290787	train-error:0.289707
# [14]	eval-error:0.288043	train-error:0.287849
# [15]	eval-error:0.285841	train-error:0.28619
# [16]	eval-error:0.283688	train-error:0.284595
# [17]	eval-error:0.281968	train-error:0.283296
# [18]	eval-error:0.280358	train-error:0.282166
# [19]	eval-error:0.278624	train-error:0.281074
# [20]	eval-error:0.277305	train-error:0.280115
# [21]	eval-error:0.27625	train-error:0.279251
# [22]	eval-error:0.275323	train-error:0.278501
# [23]	eval-error:0.274272	train-error:0.277746
# [24]	eval-error:0.273443	train-error:0.277179
# [25]	eval-error:0.272552	train-error:0.276577
# [26]	eval-error:0.27192	train-error:0.276089
# [27]	eval-error:0.27115	train-error:0.27567
# [28]	eval-error:0.27083	train-error:0.275266
# [29]	eval-error:0.270158	train-error:0.274883
# [30]	eval-error:0.26969	train-error:0.274487
# [31]	eval-error:0.26921	train-error:0.27412
# [32]	eval-error:0.268781	train-error:0.273794
# [33]	eval-error:0.26851	train-error:0.273524
# [34]	eval-error:0.26822	train-error:0.273243
# [35]	eval-error:0.267901	train-error:0.273024
# [36]	eval-error:0.267662	train-error:0.272812
# [37]	eval-error:0.267401	train-error:0.272605
# [38]	eval-error:0.2673	train-error:0.272384
# [39]	eval-error:0.267065	train-error:0.272193
# [40]	eval-error:0.266739	train-error:0.271989
# [41]	eval-error:0.266494	train-error:0.271868
# [42]	eval-error:0.266373	train-error:0.271686
# [43]	eval-error:0.266172	train-error:0.271549
# [44]	eval-error:0.266014	train-error:0.271423
# [45]	eval-error:0.265836	train-error:0.27129
# [46]	eval-error:0.265607	train-error:0.271184
# [47]	eval-error:0.265527	train-error:0.271064
# [48]	eval-error:0.265406	train-error:0.270919
# [49]	eval-error:0.265172	train-error:0.270781
# [50]	eval-error:0.265074	train-error:0.270652
# [51]	eval-error:0.264935	train-error:0.270514
# [52]	eval-error:0.264763	train-error:0.270431
# [53]	eval-error:0.264575	train-error:0.270315
# [54]	eval-error:0.264486	train-error:0.270203
# [55]	eval-error:0.264366	train-error:0.270099
# [56]	eval-error:0.26418	train-error:0.269956
# [57]	eval-error:0.264029	train-error:0.269855
# [58]	eval-error:0.263892	train-error:0.269754
# [59]	eval-error:0.26378	train-error:0.269706
# [60]	eval-error:0.263638	train-error:0.269616
# [61]	eval-error:0.263462	train-error:0.269532
# [62]	eval-error:0.263407	train-error:0.269447
# [63]	eval-error:0.263317	train-error:0.269374
# [64]	eval-error:0.263211	train-error:0.269326
# [65]	eval-error:0.263113	train-error:0.269249
# [66]	eval-error:0.26306	train-error:0.269163
# [67]	eval-error:0.263046	train-error:0.269134
# [68]	eval-error:0.262967	train-error:0.269085
# [69]	eval-error:0.26287	train-error:0.269037
# [70]	eval-error:0.262832	train-error:0.268985
# [71]	eval-error:0.26276	train-error:0.268909
# [72]	eval-error:0.262713	train-error:0.268859
# [73]	eval-error:0.262663	train-error:0.268783
# [74]	eval-error:0.262563	train-error:0.268735
# [75]	eval-error:0.262413	train-error:0.268689
# [76]	eval-error:0.262235	train-error:0.268645
# [77]	eval-error:0.262163	train-error:0.268564
# [78]	eval-error:0.262104	train-error:0.268476
# [79]	eval-error:0.262064	train-error:0.268414
# [80]	eval-error:0.261931	train-error:0.268362
# [81]	eval-error:0.261857	train-error:0.268323
# [82]	eval-error:0.261796	train-error:0.268277
# [83]	eval-error:0.26169	train-error:0.268234
# [84]	eval-error:0.261558	train-error:0.268189
# [85]	eval-error:0.26154	train-error:0.268138
# [86]	eval-error:0.261459	train-error:0.268084
# [87]	eval-error:0.261324	train-error:0.26804
# [88]	eval-error:0.261277	train-error:0.267998
# [89]	eval-error:0.261169	train-error:0.267976
# [90]	eval-error:0.261116	train-error:0.267902
# [91]	eval-error:0.261066	train-error:0.267856
# [92]	eval-error:0.261025	train-error:0.26782
# [93]	eval-error:0.260882	train-error:0.267765
# [94]	eval-error:0.26081	train-error:0.267708
# [95]	eval-error:0.260776	train-error:0.267655
# [96]	eval-error:0.260687	train-error:0.267629
# [97]	eval-error:0.260659	train-error:0.267587
# [98]	eval-error:0.260545	train-error:0.267545
# [99]	eval-error:0.260503	train-error:0.267486
# [100]	eval-error:0.260421	train-error:0.267424
# [101]	eval-error:0.260348	train-error:0.267366
# [102]	eval-error:0.260289	train-error:0.267325
# [103]	eval-error:0.260245	train-error:0.267275
# [104]	eval-error:0.260175	train-error:0.267259
# [105]	eval-error:0.26012	train-error:0.267231
# [106]	eval-error:0.260008	train-error:0.267181
# [107]	eval-error:0.259951	train-error:0.267152
# [108]	eval-error:0.259955	train-error:0.267124
# [109]	eval-error:0.259947	train-error:0.26711
# [110]	eval-error:0.259961	train-error:0.267062
# [111]	eval-error:0.259944	train-error:0.267036
# [112]	eval-error:0.259934	train-error:0.266983
# [113]	eval-error:0.259818	train-error:0.266948
# [114]	eval-error:0.259752	train-error:0.266928
# [115]	eval-error:0.259769	train-error:0.266871
# [116]	eval-error:0.259761	train-error:0.266848
# [117]	eval-error:0.259693	train-error:0.266833
# [118]	eval-error:0.259587	train-error:0.266792
# [119]	eval-error:0.259562	train-error:0.266768
# [120]	eval-error:0.259596	train-error:0.26672
# [121]	eval-error:0.259551	train-error:0.266686
# [122]	eval-error:0.259492	train-error:0.266643
# [123]	eval-error:0.259439	train-error:0.266615
# [124]	eval-error:0.259488	train-error:0.266594
# [125]	eval-error:0.259416	train-error:0.266566
# [126]	eval-error:0.259422	train-error:0.266532
# [127]	eval-error:0.259378	train-error:0.266492
# [128]	eval-error:0.259323	train-error:0.266481
# [129]	eval-error:0.25934	train-error:0.266455
# [130]	eval-error:0.259301	train-error:0.266428
# [131]	eval-error:0.259236	train-error:0.266362
# [132]	eval-error:0.259177	train-error:0.266308
# [133]	eval-error:0.259128	train-error:0.266285
# [134]	eval-error:0.259117	train-error:0.266261
# [135]	eval-error:0.259039	train-error:0.266224
# [136]	eval-error:0.259071	train-error:0.266185
# [137]	eval-error:0.259054	train-error:0.266155
# [138]	eval-error:0.259073	train-error:0.266126
# [139]	eval-error:0.25906	train-error:0.2661
# [140]	eval-error:0.259058	train-error:0.266076
# [141]	eval-error:0.258976	train-error:0.266054
# [142]	eval-error:0.258946	train-error:0.265987
# [143]	eval-error:0.258889	train-error:0.265957
# [144]	eval-error:0.25888	train-error:0.265925
# [145]	eval-error:0.258819	train-error:0.265887
# [146]	eval-error:0.258813	train-error:0.265839
# [147]	eval-error:0.25877	train-error:0.265827
# [148]	eval-error:0.25877	train-error:0.265799
# [149]	eval-error:0.258758	train-error:0.265776
# [150]	eval-error:0.258735	train-error:0.265757
# [151]	eval-error:0.258686	train-error:0.265742
# [152]	eval-error:0.258656	train-error:0.265722
# [153]	eval-error:0.25861	train-error:0.265711
# [154]	eval-error:0.258572	train-error:0.265679
# [155]	eval-error:0.258567	train-error:0.265665
# [156]	eval-error:0.258527	train-error:0.265645
# [157]	eval-error:0.258525	train-error:0.265613
# [158]	eval-error:0.258567	train-error:0.265589
# [159]	eval-error:0.258519	train-error:0.265585
# [160]	eval-error:0.258525	train-error:0.265559
# [161]	eval-error:0.258476	train-error:0.265544
# [162]	eval-error:0.258419	train-error:0.265504
# [163]	eval-error:0.258423	train-error:0.265485
# [164]	eval-error:0.258394	train-error:0.26545
# [165]	eval-error:0.258339	train-error:0.265436
# [166]	eval-error:0.258273	train-error:0.265413
# [167]	eval-error:0.258267	train-error:0.265364
# [168]	eval-error:0.258208	train-error:0.265348
# [169]	eval-error:0.258174	train-error:0.265314
# [170]	eval-error:0.258166	train-error:0.265276
# [171]	eval-error:0.258144	train-error:0.265274
# [172]	eval-error:0.258085	train-error:0.265257
# [173]	eval-error:0.258079	train-error:0.265236
# [174]	eval-error:0.258089	train-error:0.265223
# [175]	eval-error:0.258089	train-error:0.265208
# [176]	eval-error:0.258098	train-error:0.26519
# [177]	eval-error:0.258034	train-error:0.265189
# [178]	eval-error:0.258032	train-error:0.265162
# [179]	eval-error:0.257971	train-error:0.265139
# [180]	eval-error:0.257992	train-error:0.265123
# [181]	eval-error:0.257981	train-error:0.265097
# [182]	eval-error:0.257984	train-error:0.265091
# [183]	eval-error:0.257984	train-error:0.265077
# [184]	eval-error:0.257988	train-error:0.265069
# [185]	eval-error:0.258019	train-error:0.265035
# [186]	eval-error:0.258013	train-error:0.265015
# [187]	eval-error:0.257971	train-error:0.265001
# [188]	eval-error:0.257971	train-error:0.264978
# [189]	eval-error:0.25795	train-error:0.264966
# [190]	eval-error:0.257937	train-error:0.264959
# [191]	eval-error:0.257945	train-error:0.264941
# [192]	eval-error:0.257929	train-error:0.264928
# [193]	eval-error:0.257897	train-error:0.264906
# [194]	eval-error:0.257924	train-error:0.264883
# [195]	eval-error:0.257895	train-error:0.264867
# [196]	eval-error:0.257897	train-error:0.264846
# [197]	eval-error:0.257871	train-error:0.26484
# [198]	eval-error:0.257823	train-error:0.2648
# [199]	eval-error:0.257808	train-error:0.264801
# Time for training: 6708.09 seconds
# Best iteration         198

# %%
# Save model
bst.save_model("results/xgb_gblinear.model")

# %% [markdown]
# ## Validation Set Performance

# %%
# Predict using best validation set performer
prob_valid = bst.predict(dvalid)
pred_valid = [0 if x < 0.5 else 1 for x in prob_valid]

# %%
# Prediction metrics
print("Accuracy:  {:.3f}%".format(accuracy_score(y_valid, pred_valid)))
print("Precision: {:.3f}%".format(precision_score(y_valid, pred_valid)))
print("Recall:    {:.3f}%".format(recall_score(y_valid, pred_valid)))
print("F1:        {:.3f}%".format(f1_score(y_valid, pred_valid)))
# Out:
# Accuracy:  0.742%
# Precision: 0.757%
# Recall:    0.735%
# F1:        0.746%

# %%
print("Validation Confusion Matrix")
print(confusion_matrix(y_valid, pred_valid))
# Out:
# Validation Confusion Matrix
# [[191850  64095]
#  [ 71841 199490]]

# %%
# Validation set AUROC curve
fpr, tpr, threshold = roc_curve(y_valid, prob_valid)
roc_auc = auc(fpr, tpr)

fig = plt.figure(figsize=(18, 8))
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0, 1], 'r--')
plt.legend(loc = 'lower right')
plt.xlim(0,1)
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("Validation Set Receiver Operator Characteristic")
# Out:
# Text(0.5,1,'Validation Set Receiver Operator Characteristic')

# %% [markdown]
# # Test Set Performance

# %%
# Predict using best validation set performer
prob_test = bst.predict(dtest)
pred_test = [0 if x < 0.5 else 1 for x in prob_test]

# %%
# Prediction metrics
print("Accuracy:  {:.3f}%".format(accuracy_score(y_test, pred_test)))
print("Precision: {:.3f}%".format(precision_score(y_test, pred_test)))
print("Recall:    {:.3f}%".format(recall_score(y_test, pred_test)))
print("F1:        {:.3f}%".format(f1_score(y_test, pred_test)))
# Out:
# Accuracy:  0.747%
# Precision: 0.764%
# Recall:    0.743%
# F1:        0.753%

# %%
# Validation set AUROC curve
fpr, tpr, threshold = roc_curve(y_test, prob_test)
roc_auc = auc(fpr, tpr)

fig = plt.figure(figsize=(18, 8))
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0, 1], 'r--')
plt.legend(loc = 'lower right')
plt.xlim(0,1)
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("Test Set Receiver Operator Characteristic")
# Out:
# Text(0.5,1,'Test Set Receiver Operator Characteristic')
