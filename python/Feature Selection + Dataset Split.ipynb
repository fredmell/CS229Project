# %% [markdown]
# # Feature selection for Final Dataset

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from datetime import datetime
import re
from collections import Counter
from statistics import median
import os
import sys
import subprocess

# %% [markdown]
# # User Features

# %%
user_df = pd.read_csv("../data/user.tsv", sep='\t', low_memory=False)
user_df.head()
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           3.98             2957              272              2957
# 1           3.94               61                6                61
# 2           3.55                1                0                 1
# 3           4.21                5                1                 5
# 4           3.40               44                0                44
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0            3314               31              206             1300
# 1              67                1                1               16
# 2               2                0                0                4
# 3               1                0                1                1
# 4              15                1                5               18
#
#    compliment_photos  compliment_plain         ...            cool  \
# 0               1497              1353         ...           18667
# 1                  6                37         ...             377
# 2                  1                 3         ...              33
# 3                  0                 2         ...              58
# 4                  2                14         ...             226
#
#                            elite  fans  \
# 0                 2010,2011,2012   424
# 1       2007,2008,2009,2010,2011    28
# 2            2011,2012,2013,2014     4
# 3                            NaN     7
# 4  2011,2012,2013,2014,2015,2016    18
#
#                                              friends  funny     name  \
# 0  gZpsf8ZCCtksN702b0xvcg, 8U8Z7cyA7bwMZVLQ2Cmktw...  15521     Tram
# 1  Pkq6CszRZ6zjqJjjrm8f5g, T32n_y9R2lucMf9P2Lc8Rw...    163  Valarie
# 2  riS5TJ4iyQK0L9g4QlhO8w, 4rU8Yyfa9dfUiMqfnX5jdg...     26   Yvonne
# 3  rgEqPUDzo3zkq1ociN_Xqw, FEXWp5u90I88mbILkTLlvQ...     42     Jenn
# 4  c5XbGsVMiyC6RYGutY_cZg, CnQCgS1GIffv7l6vGgMvYA...    182    Asina
#
#    review_count useful                 user_id        yelping_since
# 0          2467  19997  0QeJC2inz6P-OVzROU_LNw  2009-03-10 13:55:45
# 1           250    561  jJlYRJXPdIolKbuqGiZ-CQ  2006-05-04 21:15:47
# 2           249    120  jQlrCll7ygS1ZS1vyEi94A  2010-09-29 06:45:52
# 3            63    125  DyQpYGALYV-WmKfb5rThGw  2011-01-14 21:18:08
# 4           263    666  an-ijVpGQxgiOBX9qTBOyQ  2010-12-01 19:40:25
#
# [5 rows x 22 columns]

# %% [markdown]
# Remove users who never gave reviews

# %%
user_df = user_df[user_df['review_count'] > 0]

# %%
nb_user = len(user_df)
nb_user
# Out:
# 1636115

# %%
NAs = dict()
for i in range(len(user_df.columns)):
    NAs[user_df.columns[i]] = sum(pd.isna(user_df[user_df.columns[i]]))*100/nb_user
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.2f}%'.format(key, NAs[key]))
# Out:
# NA for elite                              : 95.67%
# NA for name                               : 0.00%
# NA for average_stars                      : 0.00%
# NA for compliment_cool                    : 0.00%
# NA for compliment_cute                    : 0.00%
# NA for compliment_funny                   : 0.00%
# NA for compliment_hot                     : 0.00%
# NA for compliment_list                    : 0.00%
# NA for compliment_more                    : 0.00%
# NA for compliment_note                    : 0.00%
# NA for compliment_photos                  : 0.00%
# NA for compliment_plain                   : 0.00%
# NA for compliment_profile                 : 0.00%
# NA for compliment_writer                  : 0.00%
# NA for cool                               : 0.00%
# NA for fans                               : 0.00%
# NA for friends                            : 0.00%
# NA for funny                              : 0.00%
# NA for review_count                       : 0.00%
# NA for useful                             : 0.00%
# NA for user_id                            : 0.00%
# NA for yelping_since                      : 0.00%

# %% [markdown]
# Add seniority feature

# %%
user_df['yelping_since'] = list(map(lambda d: datetime.strptime(d, '%Y-%m-%d %H:%M:%S'), user_df['yelping_since']))

# %%
user_df['seniority'] = list(map(lambda d: int((datetime.strptime('2019-12-31', '%Y-%m-%d')-d).days), user_df['yelping_since']))

# %% [markdown]
# Add number of friends features

# %%
user_df['nb_friends'] = list(map(lambda d: len(d.split(',')), user_df['friends']))

# %% [markdown]
# Remove elite and generic columns

# %%
user_df.drop(['elite','name', 'yelping_since', 'friends'], axis=1, inplace=True)

# %%
user_df.head()
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           3.98             2957              272              2957
# 1           3.94               61                6                61
# 2           3.55                1                0                 1
# 3           4.21                5                1                 5
# 4           3.40               44                0                44
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0            3314               31              206             1300
# 1              67                1                1               16
# 2               2                0                0                4
# 3               1                0                1                1
# 4              15                1                5               18
#
#    compliment_photos  compliment_plain  compliment_profile  compliment_writer  \
# 0               1497              1353                 206               1175
# 1                  6                37                   4                  5
# 2                  1                 3                   0                  1
# 3                  0                 2                   0                  0
# 4                  2                14                   1                 25
#
#     cool  fans  funny  review_count  useful                 user_id  \
# 0  18667   424  15521          2467   19997  0QeJC2inz6P-OVzROU_LNw
# 1    377    28    163           250     561  jJlYRJXPdIolKbuqGiZ-CQ
# 2     33     4     26           249     120  jQlrCll7ygS1ZS1vyEi94A
# 3     58     7     42            63     125  DyQpYGALYV-WmKfb5rThGw
# 4    226    18    182           263     666  an-ijVpGQxgiOBX9qTBOyQ
#
#    seniority  nb_friends
# 0       3947        1703
# 1       4988         366
# 2       3379          30
# 3       3272         623
# 4       3316         332

# %%
user_describe = user_df.describe(percentiles=[.25, .5, .75, 0.9, 0.95, 0.99])
user_describe
# Out:
#        average_stars  compliment_cool  compliment_cute  compliment_funny  \
# count   1.636115e+06     1.636115e+06     1.636115e+06      1.636115e+06
# mean    3.681354e+00     3.000206e+00     1.833374e-01      3.000206e+00
# std     1.151272e+00     8.593341e+01     1.258630e+01      8.593341e+01
# min     1.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 25%     3.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 50%     3.890000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 75%     4.600000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 90%     5.000000e+00     1.000000e+00     0.000000e+00      1.000000e+00
# 95%     5.000000e+00     3.000000e+00     0.000000e+00      3.000000e+00
# 99%     5.000000e+00     3.100000e+01     2.000000e+00      3.100000e+01
# max     5.000000e+00     3.226600e+04     1.365400e+04      3.226600e+04
#
#        compliment_hot  compliment_list  compliment_more  compliment_note  \
# count    1.636115e+06     1.636115e+06     1.636115e+06     1.636115e+06
# mean     2.143368e+00     8.095947e-02     3.240047e-01     1.463122e+00
# std      7.403846e+01     1.088376e+01     1.356760e+01     6.286987e+01
# min      0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%      0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 50%      0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 75%      0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 90%      0.000000e+00     0.000000e+00     0.000000e+00     1.000000e+00
# 95%      1.000000e+00     0.000000e+00     1.000000e+00     2.000000e+00
# 99%      1.900000e+01     1.000000e+00     5.000000e+00     1.700000e+01
# max      2.497100e+04     1.266900e+04     1.350000e+04     5.783300e+04
#
#        compliment_photos  compliment_plain  compliment_profile  \
# count       1.636115e+06      1.636115e+06        1.636115e+06
# mean        1.091794e+00      2.991392e+00        2.065613e-01
# std         9.443429e+01      9.066626e+01        1.620711e+01
# min         0.000000e+00      0.000000e+00        0.000000e+00
# 25%         0.000000e+00      0.000000e+00        0.000000e+00
# 50%         0.000000e+00      0.000000e+00        0.000000e+00
# 75%         0.000000e+00      0.000000e+00        0.000000e+00
# 90%         0.000000e+00      1.000000e+00        0.000000e+00
# 95%         1.000000e+00      3.000000e+00        0.000000e+00
# 99%         7.000000e+00      2.700000e+01        2.000000e+00
# max         8.260200e+04      5.210300e+04        1.417300e+04
#
#        compliment_writer          cool          fans         funny  \
# count       1.636115e+06  1.636115e+06  1.636115e+06  1.636115e+06
# mean        1.128603e+00  2.118160e+01  1.435496e+00  1.737816e+01
# std         3.197000e+01  3.817260e+02  1.524304e+01  3.144796e+02
# min         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%         0.000000e+00  3.000000e+00  0.000000e+00  3.000000e+00
# 90%         0.000000e+00  1.300000e+01  2.000000e+00  1.300000e+01
# 95%         2.000000e+00  3.600000e+01  4.000000e+00  3.300000e+01
# 99%         1.500000e+01  2.940000e+02  2.600000e+01  2.360000e+02
# max         1.544200e+04  1.486580e+05  9.538000e+03  1.302070e+05
#
#        review_count        useful     seniority    nb_friends
# count  1.636115e+06  1.636115e+06  1.636115e+06  1.636115e+06
# mean   2.213325e+01  3.962589e+01  2.204301e+03  4.581048e+01
# std    7.532858e+01  4.468724e+02  9.463905e+02  1.350935e+02
# min    1.000000e+00  0.000000e+00  4.110000e+02  1.000000e+00
# 25%    2.000000e+00  0.000000e+00  1.480000e+03  1.000000e+00
# 50%    5.000000e+00  3.000000e+00  2.108000e+03  2.000000e+00
# 75%    1.500000e+01  1.300000e+01  2.890000e+03  3.900000e+01
# 90%    4.500000e+01  4.800000e+01  3.475000e+03  1.280000e+02
# 95%    8.900000e+01  1.100000e+02  3.850000e+03  2.180000e+02
# 99%    3.020000e+02  5.870000e+02  4.523000e+03  5.360000e+02
# max    1.327800e+04  1.542020e+05  5.557000e+03  1.499500e+04

# %%
columns_to_remove = []
for i in range(len(user_describe.columns)):
    q0 = user_describe[user_describe.columns[i]]['min']
    q90 = user_describe[user_describe.columns[i]]['90%']
    if q0 == q90:
        columns_to_remove.append(user_describe.columns[i])
columns_to_remove
# Out:
# ['compliment_cute',
#  'compliment_hot',
#  'compliment_list',
#  'compliment_more',
#  'compliment_photos',
#  'compliment_profile',
#  'compliment_writer']

# %%
user_df.drop(columns_to_remove, axis=1, inplace=True)

# %%
user_df.head()
# Out:
#    average_stars  compliment_cool  compliment_funny  compliment_note  \
# 0           3.98             2957              2957             1300
# 1           3.94               61                61               16
# 2           3.55                1                 1                4
# 3           4.21                5                 5                1
# 4           3.40               44                44               18
#  'compliment_cool',
#  'compliment_funny',
#  'compliment_note',
#  'compliment_plain',
#  'cool',
#  'fans',
#  'funny',
#  'review_count',
#  'useful',
#  'user_id',
#  'seniority',
#  'nb_friends']

# %% [markdown]
# # Business features

# %%
business_df = pd.read_csv("../data/business.tsv", sep='\t', low_memory=False)
business_df.head()
# Out:
#                    address                                         attributes  \
# 0        4 E University Dr  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 1        5588 Yonge Street  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...
# 2  617 Mount Pleasant Road  {'BusinessParking': "{'garage': False, 'street...
# 3            5969 State Rd                                                NaN
# 4        296 Rue Champlain  {'OutdoorSeating': 'True', 'RestaurantsReserva...
#
#               business_id                                         categories  \
# 0  6KgGE8B1RsR7jc9R5nuH0Q                American (Traditional), Restaurants
# 1  emyCP3Ry2SbpNrwRAtm9PQ         Restaurants, Hot Pot, Korean, Asian Fusion
# 2  YH8Bn-7pLR-SFR8MCgQj1w  Bakeries, Food, Mediterranean, French, Restaur...
# 3  RLyqeVI4a-019BRK-9IhzQ                        Shoe Repair, Local Services
# 4  OY1kLAhs9I6Ix4wUmSNAfQ     Pubs, Gastropubs, Restaurants, Nightlife, Bars
#
#                        city  \
# 0                     Tempe
# 1                North York
# 2                   Toronto
# 3                 Cleveland
# 4  Saint-Jean-sur-Richelieu
#
#                                                hours  is_open   latitude  \
# 0                                                NaN        0  33.422192
# 1  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  43.779410
# 2  {'Tuesday': '8:0-18:0', 'Wednesday': '8:0-18:0...        1  43.704166
# 3                                                NaN        1  41.400652
# 4  {'Tuesday': '11:0-3:0', 'Wednesday': '11:0-3:0...        1  45.310162
#
#     longitude                     name postal_code  review_count  stars state
# 0 -111.939615             Ruby Tuesday       85281             9    2.5    AZ
# 1  -79.415798          Pyung Won House     M2N 5S2            66    2.5    ON
# 2  -79.388212    Jules Cafe Patisserie     M4S 2M5            44    3.5    ON
# 3  -81.710151  Angelo's Cobbler Shoppe       44134             3    5.0    OH
# 4  -73.252416     Morgane Bistro & Pub     J3B 6W2             4    4.0    QC

# %% [markdown]
# Remove business which don't reviews

# %%
business_df = business_df[business_df['review_count'] > 0]

# %%
nb_business = len(business_df)
nb_business
# Out:
# 191609

# %%
NAs = dict()
for i in range(len(business_df.columns)):
    NAs[business_df.columns[i]] = sum(pd.isna(business_df[business_df.columns[i]]))*100/nb_business
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.2f}%'.format(key, NAs[key]))
# Out:
# NA for hours                              : 23.27%
# NA for attributes                         : 14.97%
# NA for address                            : 3.99%
# NA for postal_code                        : 0.34%
# NA for categories                         : 0.25%
# NA for city                               : 0.00%
# NA for business_id                        : 0.00%
# NA for is_open                            : 0.00%
# NA for latitude                           : 0.00%
# NA for longitude                          : 0.00%
# NA for name                               : 0.00%
# NA for review_count                       : 0.00%
# NA for stars                              : 0.00%
# NA for state                              : 0.00%

# %%
business_df.dropna(inplace=True)

# %%
business_df.head()
# Out:
#                     address  \
# 1         5588 Yonge Street
# 2   617 Mount Pleasant Road
# 4         296 Rue Champlain
# 6  1216 East Washington Ave
# 8          2541 N Cherry Rd
#
#                                           attributes             business_id  \
# 1  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...  emyCP3Ry2SbpNrwRAtm9PQ
# 2  {'BusinessParking': "{'garage': False, 'street...  YH8Bn-7pLR-SFR8MCgQj1w
# 4  {'OutdoorSeating': 'True', 'RestaurantsReserva...  OY1kLAhs9I6Ix4wUmSNAfQ
# 6  {'Caters': 'False', 'RestaurantsTakeOut': 'Tru...  J0P152h7wimvdJ-aV0QLug
# 8  {'RestaurantsTakeOut': 'True', 'BikeParking': ...  pvXdMR9tcQlwXcXJLllmPg
#
#                                           categories  \
# 1         Restaurants, Hot Pot, Korean, Asian Fusion
# 2  Bakeries, Food, Mediterranean, French, Restaur...
# 4     Pubs, Gastropubs, Restaurants, Nightlife, Bars
# 6                                 Food, Coffee & Tea
# 8  Automotive, Convenience Stores, Gas Stations, ...
#
#                        city  \
# 1                North York
# 2                   Toronto
# 4  Saint-Jean-sur-Richelieu
# 6                   Madison
# 8                 Rock Hill
#
#                                                hours  is_open   latitude  \
# 1  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  43.779410
# 2  {'Tuesday': '8:0-18:0', 'Wednesday': '8:0-18:0...        1  43.704166
# 4  {'Tuesday': '11:0-3:0', 'Wednesday': '11:0-3:0...        1  45.310162
# 6  {'Monday': '6:0-19:0', 'Tuesday': '6:0-19:0', ...        1  43.086294
# 8  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        0  34.971428
#
#    longitude                   name postal_code  review_count  stars state
# 1 -79.415798        Pyung Won House     M2N 5S2            66    2.5    ON
# 2 -79.388212  Jules Cafe Patisserie     M4S 2M5            44    3.5    ON
# 4 -73.252416   Morgane Bistro & Pub     J3B 6W2             4    4.0    QC
# 6 -89.368132     Stone Creek Coffee       53703            38    4.5    WI
# 8 -80.990601       Kangaroo Express       29733             3    4.0    SC

# %%
def unnest_dictionary(nested_dico):
    unnested_dico = nested_dico.copy()
    
    finished = False
    while not finished:
        finished = True

        keys = list(unnested_dico.keys())

        for key in keys:

            attributes = str(unnested_dico[key])
            if re.match(r'{.*:.*}', attributes):

                # Sub dico with the keys
                key_dico = eval(attributes)
                sub_dico = {'{}_{}'.format(key, elt): str(key_dico[elt]) for elt in key_dico}

                # Update output dictionary
                unnested_dico.pop(key, None)
                unnested_dico = {**unnested_dico, **sub_dico}

                # Since we found at least one value which one a dictionary we set finished
                # to false to do another loop and the check if the value that was unnested
                # could be even more unnested
                finished = False

    unnested_dico = {key: re.sub(r"[a-z]'(.*)'", r'\1', str(unnested_dico[key])) for key in unnested_dico}
    unnested_dico = {key: re.sub(r"'", '', unnested_dico[key]) for key in unnested_dico}
    return unnested_dico

# %%
nested_key = 'attributes'
business_df[nested_key] = list(map(lambda x: unnest_dictionary(eval(str(x))), business_df[nested_key].values))

# %%
nested_key = 'hours'
business_df[nested_key] = list(map(lambda x: unnest_dictionary(eval(str(x))), business_df[nested_key].values))

# %%
business_df.head()
# Out:
#                     address  \
# 1         5588 Yonge Street
# 2   617 Mount Pleasant Road
# 4         296 Rue Champlain
# 6  1216 East Washington Ave
# 8          2541 N Cherry Rd
#
#                                           attributes             business_id  \
# 1  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...  emyCP3Ry2SbpNrwRAtm9PQ
# 2  {'RestaurantsAttire': 'casual', 'RestaurantsGo...  YH8Bn-7pLR-SFR8MCgQj1w
# 4  {'OutdoorSeating': 'True', 'RestaurantsReserva...  OY1kLAhs9I6Ix4wUmSNAfQ
# 6  {'Caters': 'False', 'RestaurantsTakeOut': 'Tru...  J0P152h7wimvdJ-aV0QLug
# 8  {'RestaurantsTakeOut': 'True', 'BikeParking': ...  pvXdMR9tcQlwXcXJLllmPg
#
#                                           categories  \
# 1         Restaurants, Hot Pot, Korean, Asian Fusion
# 2  Bakeries, Food, Mediterranean, French, Restaur...
# 4     Pubs, Gastropubs, Restaurants, Nightlife, Bars
# 6                                 Food, Coffee & Tea
# 8  Automotive, Convenience Stores, Gas Stations, ...
#
#                        city  \
# 1                North York
# 2                   Toronto
# 4  Saint-Jean-sur-Richelieu
# 6                   Madison
# 8                 Rock Hill
#
#                                                hours  is_open   latitude  \
# 1  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  43.779410
# 2  {'Tuesday': '8:0-18:0', 'Wednesday': '8:0-18:0...        1  43.704166
# 4  {'Tuesday': '11:0-3:0', 'Wednesday': '11:0-3:0...        1  45.310162
# 6  {'Monday': '6:0-19:0', 'Tuesday': '6:0-19:0', ...        1  43.086294
# 8  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        0  34.971428
#
#    longitude                   name postal_code  review_count  stars state
# 1 -79.415798        Pyung Won House     M2N 5S2            66    2.5    ON
# 2 -79.388212  Jules Cafe Patisserie     M4S 2M5            44    3.5    ON
# 4 -73.252416   Morgane Bistro & Pub     J3B 6W2             4    4.0    QC
# 6 -89.368132     Stone Creek Coffee       53703            38    4.5    WI
# 8 -80.990601       Kangaroo Express       29733             3    4.0    SC

# %%
business_df = pd.concat([business_df.drop(['attributes'], axis=1), business_df['attributes'].apply(pd.Series)], axis=1)

# %%
business_df = pd.concat([business_df.drop(['hours'], axis=1), business_df['hours'].apply(pd.Series)], axis=1)

# %%
nb_business = len(business_df)
nb_business
# Out:
# 123933

# %%
NAs = dict()
for i in range(len(business_df.columns)):
    NAs[business_df.columns[i]] = sum(pd.isna(business_df[business_df.columns[i]]))*100/nb_business

# %%
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.2f}%'.format(key, NAs[key]))
# Out:
# NA for BestNights                         : 99.99%
# NA for DietaryRestrictions                : 99.99%
# NA for RestaurantsCounterService          : 99.99%
# NA for Open24Hours                        : 99.99%
# NA for BYOB                               : 99.98%
# NA for HairSpecializesIn                  : 99.98%
# NA for DietaryRestrictions_dairy-free     : 99.96%
# NA for DietaryRestrictions_gluten-free    : 99.96%
# NA for DietaryRestrictions_vegan          : 99.96%
# NA for DietaryRestrictions_kosher         : 99.96%
# NA for DietaryRestrictions_halal          : 99.96%
# NA for DietaryRestrictions_soy-free       : 99.96%
# NA for DietaryRestrictions_vegetarian     : 99.96%
# NA for AgesAllowed                        : 99.91%
# NA for Music                              : 99.86%
# NA for GoodForMeal                        : 99.85%
# NA for Ambience                           : 99.67%
# NA for Corkage                            : 99.57%
# NA for HairSpecializesIn_straightperms    : 99.38%
# NA for HairSpecializesIn_africanamerican  : 99.38%
# NA for HairSpecializesIn_asian            : 99.38%
# NA for HairSpecializesIn_coloring         : 99.27%
# NA for HairSpecializesIn_extensions       : 99.27%
# NA for HairSpecializesIn_curly            : 99.27%
# NA for HairSpecializesIn_kids             : 99.27%
# NA for HairSpecializesIn_perms            : 99.27%
# NA for BYOBCorkage                        : 99.07%
# NA for BusinessParking                    : 98.52%
# NA for DriveThru                          : 97.70%
# NA for CoatCheck                          : 97.38%
# NA for BestNights_monday                  : 97.36%
# NA for BestNights_tuesday                 : 97.36%
# NA for BestNights_friday                  : 97.36%
# NA for BestNights_wednesday               : 97.36%
# NA for BestNights_thursday                : 97.36%
# NA for BestNights_sunday                  : 97.36%
# NA for BestNights_saturday                : 97.36%
# NA for Smoking                            : 97.35%
# NA for Music_no_music                     : 97.06%
# NA for Music_background_music             : 96.68%
# NA for Music_karaoke                      : 96.68%
# NA for Music_video                        : 96.68%
# NA for Music_jukebox                      : 96.66%
# NA for Music_live                         : 96.65%
# NA for GoodForDancing                     : 96.50%
# NA for Music_dj                           : 96.30%
# NA for HappyHour                          : 96.20%
# NA for AcceptsInsurance                   : 94.83%
# NA for DogsAllowed                        : 94.28%
# NA for BusinessAcceptsBitcoin             : 90.89%
# NA for RestaurantsTableService            : 87.43%
# NA for WheelchairAccessible               : 84.77%
# NA for GoodForMeal_dessert                : 78.75%
# NA for GoodForMeal_latenight              : 78.75%
# NA for GoodForMeal_lunch                  : 78.75%
# NA for GoodForMeal_dinner                 : 78.75%
# NA for GoodForMeal_breakfast              : 78.75%
# NA for GoodForMeal_brunch                 : 78.75%
# NA for Ambience_divey                     : 73.60%
# NA for Caters                             : 71.95%
# NA for NoiseLevel                         : 71.28%
# NA for ByAppointmentOnly                  : 69.64%
# NA for RestaurantsAttire                  : 69.36%
# NA for Ambience_hipster                   : 69.16%
# NA for Ambience_upscale                   : 68.99%
# NA for Ambience_romantic                  : 68.92%
# NA for Ambience_intimate                  : 68.92%
# NA for Ambience_classy                    : 68.92%
# NA for Ambience_touristy                  : 68.92%
# NA for Ambience_trendy                    : 68.92%
# NA for Ambience_casual                    : 68.92%
# NA for Alcohol                            : 68.79%
# NA for HasTV                              : 68.61%
# NA for RestaurantsReservations            : 66.59%
# NA for WiFi                               : 66.58%
# NA for RestaurantsDelivery                : 66.39%
# NA for RestaurantsGoodForGroups           : 65.84%
# NA for OutdoorSeating                     : 65.33%
# NA for RestaurantsTakeOut                 : 60.63%
# NA for GoodForKids                        : 58.94%
# NA for BikeParking                        : 42.51%
# NA for BusinessParking_validated          : 35.60%
# NA for BusinessParking_street             : 35.60%
# NA for BusinessParking_lot                : 35.60%
# NA for BusinessParking_valet              : 35.59%
# NA for BusinessParking_garage             : 35.59%
# NA for Sunday                             : 34.75%
# NA for RestaurantsPriceRange2             : 32.74%
# NA for BusinessAcceptsCreditCards         : 28.42%
# NA for Saturday                           : 12.70%
# NA for Monday                             : 8.68%
# NA for Tuesday                            : 3.09%
# NA for Wednesday                          : 1.76%
# NA for Friday                             : 1.66%
# NA for Thursday                           : 1.24%
# NA for address                            : 0.00%
# NA for business_id                        : 0.00%
# NA for categories                         : 0.00%
# NA for city                               : 0.00%
# NA for is_open                            : 0.00%
# NA for latitude                           : 0.00%
# NA for longitude                          : 0.00%
# NA for name                               : 0.00%
# NA for postal_code                        : 0.00%
# NA for review_count                       : 0.00%
# NA for stars                              : 0.00%
# NA for state                              : 0.00%

# %%
d = dict(Counter(business_df['categories']))
categories = list(set(business_df['categories'].values))
values = [d[x] for x in categories]
category_count = pd.DataFrame.from_dict({'Category': categories, 'Nb': values})

# %%
category_count.head()
# Out:
#                                             Category  Nb
# 0  Massage, Health & Medical, Medical Centers, Be...   1
# 1  Nightlife, Bars, Italian, Sports Bars, Restaur...   1
# 2  Fitness & Instruction, Trainers, Active Life, ...   1
# 3  Nightlife, Canadian (New), Restaurants, Americ...   1
# 4  Wholesale Stores, Shopping, Home Services, Flo...   1

# %%
len(category_count['Nb'])
# Out:
# 72082

# %% [markdown]
# # Review Features

# %%
review_df = pd.read_csv("../data/review.tsv", sep='\t', low_memory=False)
review_df.head()
# Out:
#               business_id  cool                 date  funny  \
# 0  039QG6ks4UYNkMA3mcII2A   0.0  2012-05-28 16:42:56    0.0
# 1  vx4YAA02Qz6khRD1fZ1MFA   1.0  2012-06-25 23:45:43    0.0
# 2  k2b3niokS_tosjah_rzCPw   5.0  2017-02-19 06:21:58    2.0
# 3  77h11eWv6HKJAgojLx8G4w   0.0  2017-01-02 05:04:15    0.0
# 4  -BJVR_DO5r-MfQ2tiszeOg   1.0  2010-08-21 06:53:33    0.0
#
#                 review_id  stars  \
# 0  qVBtM3H5xFUMweX1qGsOnA    5.0
# 1  s8x0OQNXxIlhepz1m_ofjg    3.0
# 2  gi_-cTGatAcR5Ko_AI1Paw    4.0
# 3  Bs-HZwbbqeWpgzl5T1_QyA    4.0
# 4  VRDNOiSG6h2tYXPKwpf75w    5.0
#
#                                                 text  useful  \
# 0  My boyfriend and I were really looking forward...     8.0
# 1  Not bad at all.  The standard dishes - chinese...     2.0
# 2  I ordered the Heart Shaped pizza and meatball ...     4.0
# 3  I knew coming here, there would be a long line...     0.0
# 4  Wow...no reviews on here yet? I am surprised.....     9.0
#
#                   user_id
# 0  sThIuQa4EE8WocfxVFWMlA
# 1  llyK5_o-6L9H5QG2rcROmA
# 2  uc9ITBuspRFkl-S3Bo90dg
# 3  EIRBAYXCV3647N3ejEwkIA
# 4  Mq8Su0PZC8D4EaJrLJOhYw

# %%
nb_reviews = len(review_df)
NAs = dict()
for i in range(len(review_df.columns)):
    NAs[review_df.columns[i]] = sum(pd.isna(review_df[review_df.columns[i]]))*100/nb_reviews
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NAs[key]))
# Out:
# NA for useful                             : 0.000568%
# NA for user_id                            : 0.000568%
# NA for text                               : 0.000404%
# NA for funny                              : 0.000374%
# NA for review_id                          : 0.000374%
# NA for stars                              : 0.000374%
# NA for cool                               : 0.000180%
# NA for date                               : 0.000180%
# NA for business_id                        : 0.000000%

# %%
review_df.dropna(inplace=True)

# %%
review_df['label'] = list(map(lambda x: int(int(x) == 5), review_df['stars'].values))
review_df = review_df[['review_id', 'business_id', 'user_id', 'label']]

# %%
review_df.head()
# Out:
#                 review_id             business_id                 user_id  \
# 0  qVBtM3H5xFUMweX1qGsOnA  039QG6ks4UYNkMA3mcII2A  sThIuQa4EE8WocfxVFWMlA
# 1  s8x0OQNXxIlhepz1m_ofjg  vx4YAA02Qz6khRD1fZ1MFA  llyK5_o-6L9H5QG2rcROmA
# 2  gi_-cTGatAcR5Ko_AI1Paw  k2b3niokS_tosjah_rzCPw  uc9ITBuspRFkl-S3Bo90dg
# 3  Bs-HZwbbqeWpgzl5T1_QyA  77h11eWv6HKJAgojLx8G4w  EIRBAYXCV3647N3ejEwkIA
# 4  VRDNOiSG6h2tYXPKwpf75w  -BJVR_DO5r-MfQ2tiszeOg  Mq8Su0PZC8D4EaJrLJOhYw
#
#    label
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1

# %%
nb_reviews = len(review_df)
nb_reviews
# Out:
# 6684885

# %% [markdown]
# # Merge data sets

# %%
df = pd.merge(review_df, user_df, on='user_id', how='inner')

# %%
df = pd.merge(df, business_df, on='business_id', how='inner')

# %%
del review_df
del user_df
del business_df

# %%
df.rename(columns={"review_count_x": "user_review_count", "review_count_y": "business_review_count"}, inplace=True)

# %%
df.drop(['name', 'address', 'city', 'state'], axis=1, inplace=True)

# %%
df_back_up = df.copy()

# %%
df = df_back_up.copy()

# %%
df.head()
# Out:
#                 review_id             business_id                 user_id  \
# 0  qVBtM3H5xFUMweX1qGsOnA  039QG6ks4UYNkMA3mcII2A  sThIuQa4EE8WocfxVFWMlA
# 1  Gl89V498xtdBau2eiZucgg  039QG6ks4UYNkMA3mcII2A  L8P5OWO1Jh4B2HLa1Fnbng
# 2  qehrOK2n_7p6k4bVhJtIPA  039QG6ks4UYNkMA3mcII2A  b3L68_hF3aZBQKXCFoG0PQ
# 3  32afZohbF1u3y7MeiusVHg  039QG6ks4UYNkMA3mcII2A  LHKSDD_2JJrsP5LyklZBJQ
# 4  HGizmU-su3Z37gZg6tAtVw  039QG6ks4UYNkMA3mcII2A  tTzxvWvelW6x3rJxSka59A
#
#    label  average_stars  compliment_cool  compliment_funny  compliment_note  \
# 0      1           4.68                1                 1                0
# 1      1           3.27                6                 6               15
# 2      0           4.23                4                 4                1
# 3      1           5.00                1                 1                1
# 4      1           4.67                0                 0                0
#
#    compliment_plain  cool    ...      Open24Hours  DietaryRestrictions  \
# 0                 0    10    ...              NaN                  NaN
# 1                12   654    ...              NaN                  NaN
# 2                 2    25    ...              NaN                  NaN
# 3                 1     2    ...              NaN                  NaN
# 4                 0     1    ...              NaN                  NaN
#
#    RestaurantsCounterService    Monday   Tuesday  Wednesday  Thursday  \
# 0                        NaN  9:0-19:0  9:0-19:0   9:0-19:0  9:0-19:0
# 1                        NaN  9:0-19:0  9:0-19:0   9:0-19:0  9:0-19:0
# 2                        NaN  9:0-19:0  9:0-19:0   9:0-19:0  9:0-19:0
# 3                        NaN  9:0-19:0  9:0-19:0   9:0-19:0  9:0-19:0
# 4                        NaN  9:0-19:0  9:0-19:0   9:0-19:0  9:0-19:0
#
#      Friday  Saturday     Sunday
# 0  9:0-19:0  9:0-19:0  10:0-16:0
# 1  9:0-19:0  9:0-19:0  10:0-16:0
# 2  9:0-19:0  9:0-19:0  10:0-16:0
# 3  9:0-19:0  9:0-19:0  10:0-16:0
# 4  9:0-19:0  9:0-19:0  10:0-16:0
#
# [5 rows x 118 columns]

# %% [markdown]
# # Mapping categorical to numerical values

# %% [markdown]
# ## Print unique values to create mapping

# %%
categorical_columns = []
other_columns = []
for i in range(len(df.columns)):
    col = df.columns[i]
    unique_values = list(set(df[col].values))
    nb = len(unique_values)
    if nb < 20:
        categorical_columns.append(col)
        print(col)
        print(unique_values)
        print()
    else:
        other_columns.append(col)
# Out:
# label
# [0, 1]
#
# is_open
# [0, 1]
#
# stars
# [1.0, 2.0, 3.0, 3.5, 5.0, 4.5, 4.0, 2.5, 1.5]
#
# RestaurantsPriceRange2
# ['3', nan, '4', '2', '1', 'None']
#
# RestaurantsAttire
# [nan, 'casual', 'formal', 'dressy', 'None']
#
# RestaurantsGoodForGroups
# [nan, 'True', 'None', 'False']
#
# GoodForKids
# [nan, 'True', 'None', 'False']
#
# RestaurantsReservations
# [nan, 'True', 'None', 'False']
#
# Alcohol
# [nan, 'full_bar', 'beer_and_wine', 'None', 'none']
#
# Caters
# [nan, 'True', 'None', 'False']
#
# NoiseLevel
# [nan, 'very_loud', 'quiet', 'loud', 'average', 'None']
#
# HasTV
# [nan, 'True', 'None', 'False']
#
# BikeParking
# [nan, 'True', 'None', 'False']
#
# RestaurantsDelivery
# [nan, 'True', 'None', 'False']
#
# WiFi
# [nan, 'free', 'no', 'paid', 'None']
#
# OutdoorSeating
# [nan, 'True', 'None', 'False']
#
# RestaurantsTakeOut
# [nan, 'True', 'None', 'False']
#
# GoodForMeal_dessert
# [nan, 'True', 'False']
#
# GoodForMeal_latenight
# [nan, 'True', 'False']
#
# GoodForMeal_lunch
# [nan, 'True', 'False']
#
# GoodForMeal_dinner
# [nan, 'True', 'False']
#
# GoodForMeal_brunch
# [nan, 'True', 'False']
#
# GoodForMeal_breakfast
# [nan, 'True', 'False']
#
# BusinessParking_garage
# [nan, 'True', 'False']
#
# BusinessParking_street
# [nan, 'True', 'False']
#
# BusinessParking_validated
# [nan, 'True', 'False']
#
# BusinessParking_lot
# [nan, 'True', 'False']
#
# BusinessParking_valet
# [nan, 'True', 'False']
#
# Ambience_romantic
# [nan, 'True', 'False']
#
# Ambience_intimate
# [nan, 'True', 'False']
#
# Ambience_classy
# [nan, 'True', 'False']
#
# Ambience_hipster
# [nan, 'True', 'False']
#
# Ambience_divey
# [nan, 'True', 'False']
#
# Ambience_touristy
# [nan, 'True', 'False']
#
# Ambience_trendy
# [nan, 'True', 'False']
#
# Ambience_upscale
# [nan, 'True', 'False']
#
# Ambience_casual
# [nan, 'True', 'False']
#
# BusinessAcceptsCreditCards
# [nan, 'True', 'None', 'False']
#
# GoodForDancing
# [nan, 'True', 'None', 'False']
#
# HappyHour
# [nan, 'True', 'None', 'False']
#
# ByAppointmentOnly
# [nan, 'True', 'None', 'False']
#
# WheelchairAccessible
# [nan, 'True', 'None', 'False']
#
# HairSpecializesIn_straightperms
# [nan, 'True', 'False']
#
# HairSpecializesIn_coloring
# [nan, 'True', 'False']
#
# HairSpecializesIn_extensions
# [nan, 'True', 'False']
#
# HairSpecializesIn_africanamerican
# [nan, 'True', 'False']
#
# HairSpecializesIn_curly
# [nan, 'True', 'False']
#
# HairSpecializesIn_kids
# [nan, 'True', 'False']
#
# HairSpecializesIn_perms
# [nan, 'True', 'False']
#
# HairSpecializesIn_asian
# [nan, 'True', 'False']
#
# BusinessAcceptsBitcoin
# [nan, 'True', 'None', 'False']
#
# DogsAllowed
# [nan, 'True', 'None', 'False']
#
# CoatCheck
# [nan, 'True', 'None', 'False']
#
# Smoking
# [nan, 'no', 'outdoor', 'yes', 'None']
#
# RestaurantsTableService
# [nan, 'True', 'None', 'False']
#
# DriveThru
# [nan, 'True', 'None', 'False']
#
# AcceptsInsurance
# [nan, 'True', 'None', 'False']
#
# BYOBCorkage
# [nan, 'yes_free', 'no', 'yes_corkage', 'None']
#
# BusinessParking
# [nan, '{}', 'None']
#
# Music_dj
# [nan, 'True', 'False']
#
# Music_background_music
# [nan, 'True', 'False']
#
# Music_no_music
# [nan, 'False']
#
# Music_jukebox
# [nan, 'True', 'False']
#
# Music_live
# [nan, 'True', 'False']
#
# Music_video
# [nan, 'True', 'False']
#
# Music_karaoke
# [nan, 'True', 'False']
#
# BestNights_monday
# [nan, 'True', 'False']
#
# BestNights_tuesday
# [nan, 'True', 'False']
#
# BestNights_friday
# [nan, 'True', 'False']
#
# BestNights_wednesday
# [nan, 'True', 'False']
#
# BestNights_thursday
# [nan, 'True', 'False']
#
# BestNights_sunday
# [nan, 'True', 'False']
#
# BestNights_saturday
# [nan, 'True', 'False']
#
# Corkage
# [nan, 'True', 'False']
#
# Ambience
# [nan, 'None']
#
# Music
# [nan, '{}', 'None']
#
# AgesAllowed
# [nan, '18plus', 'allages', 'None', '21plus', '19plus']
#
# BYOB
# [nan, 'True', 'False']
#
# GoodForMeal
# [nan, '{}', 'None']
#
# DietaryRestrictions_dairy-free
# [nan, 'True', 'False']
#
# DietaryRestrictions_gluten-free
# [nan, 'True', 'False']
#
# DietaryRestrictions_vegan
# [nan, 'True', 'False']
#
# DietaryRestrictions_kosher
# [nan, 'False']
#
# DietaryRestrictions_halal
# [nan, 'True', 'False']
#
# DietaryRestrictions_soy-free
# [nan, 'False']
#
# DietaryRestrictions_vegetarian
# [nan, 'True', 'False']
#
# BestNights
# [nan, 'None']
#
# HairSpecializesIn
# [nan, 'None']
#
# Open24Hours
# [nan, 'True', 'False']
#
# DietaryRestrictions
# [nan, 'None']
#
# RestaurantsCounterService
# [nan, 'True', 'False']

# %%
for col in other_columns:
    print(col)
# Out:
# review_id
# business_id
# user_id
# average_stars
# compliment_cool
# compliment_funny
# compliment_note
# compliment_plain
# cool
# fans
# funny
# user_review_count
# useful
# seniority
# nb_friends
# categories
# latitude
# longitude
# postal_code
# business_review_count
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sun
'4.52', '2.99', '2.74', '2.24', '2.49', '3.24', '3.99', '3.74', '3.49', '4.24', '4.49', '4.74', '4.99', '1.6', '1.85', '1.1', '1.35', '2.1', '2.6', '2.85', '2.35', '3.85', '3.6', '3.35', '3.1', '1.78', '1.28', '1.71', '1.96', '1.21', '1.46', '2.71', '2.96', '2.46', '2.21', '3.46', '3.96', '3.71', '3.21', '4.96', '4.21', '4.71', '4.46', '1.39', '2.32', '2.07', '3.32', '3.82', '3.07', '1.91', '1.95', '1.57', '1.2', '1.99', '1.74', '1.07', '1.86', '1.53', '1.11', '4.43', '4.18', '4.93', '4.9', '4.15', '4.4', '4.65', '1.87', '1.62', '1.37', '1.12', '2.62', '2.87', '2.37', '2.12', '3.87', '3.37', '3.62', '3.12', '4.12', '4.37', '4.62', '4.87', '1.3', '1.05', '1.73', '1.98', '1.23', '1.48', '2.98', '2.73', '2.48', '2.23', '3.48', '3.98', '3.23', '1.41', '1.66', '1.16', '2.59', '2.84', '2.09', '2.34', '3.59', '3.84', '3.34', '4.34', '4.84', '4.09', '4.59', '4.06', '4.31', '4.8100000000000005', '4.78', '4.03', '4.28', '4.53', '2.89', '2.64', '2.14', '2.39', '3.89', '3.64', '3.14', '3.39', '1.82', '1.32']

# %% [markdown]
# ## Mapping

# %%
cat_to_num_mapping = {'AcceptsInsurance': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0},
                      'AgesAllowed': {np.nan: np.nan, 'None': 0, '18plus': 1, '19plus': 2, '21plus': 3, 'allages': 4},
                      'Alcohol': {np.nan: np.nan, 'None': 0, 'none': 0, 'full_bar': 1, 'beer_and_wine': 2},
                      'Ambience': {np.nan: np.nan, 'None': 0},
                      'Ambience_casual': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'Ambience_classy': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_divey': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_hipster': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_intimate': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_romantic': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_touristy': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_trendy': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Ambience_upscale': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'BestNights': {np.nan: np.nan, 'None': 0},
                      'BestNights_friday': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'BestNights_monday': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'BestNights_saturday': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'BestNights_sunday': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'BestNights_thursday': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'BestNights_tuesday': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'BestNights_wednesday': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'BikeParking': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'BusinessAcceptsBitcoin': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'BusinessAcceptsCreditCards': {'True': 1, np.nan: np.nan, 'False': 0, 'None': 0},
                      'BusinessParking': {np.nan: np.nan, '{}': 0, 'None': 0},
                      'BusinessParking_garage': {'True': 1, 'False': 0, np.nan: np.nan},
                      'BusinessParking_lot': {'True': 1, 'False': 0, np.nan: np.nan},
                      'BusinessParking_street': {'True': 1, 'False': 0, np.nan: np.nan},
                      'BusinessParking_valet': {'True': 1, 'False': 0, np.nan: np.nan},
                      'BusinessParking_validated': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'ByAppointmentOnly': {'True': 1, np.nan: np.nan, 'False': 0, 'None': 0},
                      'BYOB': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'BYOBCorkage': {np.nan: np.nan, 'yes_free': 1, 'None': 0, 'yes_corkage': 1, 'no': 0},
                      'Caters': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'CoatCheck': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'Corkage': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'DietaryRestrictions': {np.nan: np.nan, 'None': 0},
                      'DietaryRestrictions_dairy-free': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'DietaryRestrictions_gluten-free': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'DietaryRestrictions_halal': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'DietaryRestrictions_kosher': {np.nan: np.nan, 'False': 0},
                      'DietaryRestrictions_soy-free': {np.nan: np.nan, 'False': 0},
                      'DietaryRestrictions_vegan': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'DietaryRestrictions_vegetarian': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'DogsAllowed': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'DriveThru': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'GoodForDancing': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'GoodForKids': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0},
                      'GoodForMeal': {np.nan: np.nan, '{}': 0, 'None': 0},
                      'GoodForMeal_breakfast': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'GoodForMeal_brunch': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'GoodForMeal_dessert': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'GoodForMeal_dinner': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'GoodForMeal_latenight': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'GoodForMeal_lunch': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'HairSpecializesIn': {np.nan: np.nan, 'None': 0},
                      'HairSpecializesIn_africanamerican': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'HairSpecializesIn_asian': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'HairSpecializesIn_coloring': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'HairSpecializesIn_curly': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'HairSpecializesIn_extensions': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'HairSpecializesIn_kids': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'HairSpecializesIn_perms': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'HairSpecializesIn_straightperms': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'HappyHour': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0},
                      'HasTV': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'Music': {np.nan: np.nan, '{}': 0, 'None': 0},
                      'Music_background_music': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Music_dj': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Music_jukebox': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Music_karaoke': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'Music_live': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'Music_no_music': {np.nan: np.nan, 'False': 0},
                      'Music_video': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'NoiseLevel': {np.nan: np.nan, 'None': 0, 'quiet': 1, 'average': 2, 'loud': 3, 'very_loud': 4},
                      'Open24Hours': {np.nan: np.nan, 'True': 1, 'False': 0},
                      'OutdoorSeating': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'RestaurantsAttire': {np.nan: np.nan, 'None': 0, 'casual': 1, 'dressy': 2, 'formal': 3},
                      'RestaurantsCounterService': {np.nan: np.nan, 'False': 0, 'True': 1},
                      'RestaurantsDelivery': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'RestaurantsGoodForGroups': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0},
                      'RestaurantsPriceRange2': {np.nan: np.nan, '1': 1, 'None': 0, '2': 2, '3': 3, '4': 4},
                      'RestaurantsReservations': {np.nan: np.nan, 'False': 0, 'None': 0, 'True': 1},
                      'RestaurantsTableService': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0, 'none': 0},
                      'RestaurantsTakeOut': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0},
                      'Smoking': {np.nan: np.nan, 'None': 0, 'outdoor': 2, 'yes': 1, 'no': 0},
                      'WheelchairAccessible': {np.nan: np.nan, 'True': 1, 'False': 0, 'None': 0},
                      'WiFi': {np.nan: np.nan, 'paid': 2, 'None': 0, 'free': 1, 'no': 0}
                      }

# %%
df.dtypes
# Out:
# review_id                           object
# business_id                         object
# user_id                             object
# label                                int64
# average_stars                      float64
# compliment_cool                      int64
# compliment_funny                     int64
# compliment_note                      int64
# compliment_plain                     int64
# cool                                 int64
# fans                                 int64
# funny                                int64
# user_review_count                    int64
# useful                               int64
# seniority                            int64
# nb_friends                           int64
# categories                          object
# is_open                              int64
# latitude                           float64
# longitude                          float64
# postal_code                         object
# business_review_count                int64
# stars                              float64
# RestaurantsPriceRange2              object
# RestaurantsAttire                   object
# RestaurantsGoodForGroups            object
# GoodForKids                         object
# RestaurantsReservations             object
# Alcohol                             object
# Caters                              object
#                                     ...
# BestNights_friday                   object
# BestNights_wednesday                object
# BestNights_thursday                 object
# BestNights_sunday                   object
# BestNights_saturday                 object
# Corkage                             object
# Ambience                            object
# Music                               object
# AgesAllowed                         object
# BYOB                                object
# GoodForMeal                         object
# DietaryRestrictions_dairy-free      object
# DietaryRestrictions_gluten-free     object
# DietaryRestrictions_vegan           object
# DietaryRestrictions_kosher          object
# DietaryRestrictions_halal           object
# DietaryRestrictions_soy-free        object
# DietaryRestrictions_vegetarian      object
# BestNights                          object
# HairSpecializesIn                   object
# Open24Hours                         object
# DietaryRestrictions                 object
# RestaurantsCounterService           object
# Monday                              object
# Tuesday                             object
# Wednesday                           object
# Thursday                            object
# Friday                              object
# Saturday                            object
# Sunday                              object
# Length: 118, dtype: object

# %%
def convert_to_double(element):
    if pd.isna(element):
        return np.nan
    else:
        return np.double(element)

# %%
def convert_to_str(element):
    if pd.isna(element):
        return np.nan
    else:
        return str(element)

# %%
for i in range(len(df.columns)):
    column = df.columns[i]
    if column in cat_to_num_mapping:
        df[df.columns[i]] = list(map(lambda x: cat_to_num_mapping[column][x], df[df.columns[i]].values))
    else:
        try:
            df[df.columns[i]] = list(map(convert_to_double, df[df.columns[i]].values))
        except:
            df[df.columns[i]] = list(map(convert_to_str, df[df.columns[i]].values))
    print('{:03d} {:35s}'.format(i, column), type(df[column][0]))
# Out:
# 000 review_id                           <class 'str'>
# 001 business_id                         <class 'str'>
# 002 user_id                             <class 'str'>
# 003 label                               <class 'numpy.float64'>
# 004 average_stars                       <class 'numpy.float64'>
# 005 compliment_cool                     <class 'numpy.float64'>
# 006 compliment_funny                    <class 'numpy.float64'>
# 007 compliment_note                     <class 'numpy.float64'>
# 008 compliment_plain                    <class 'numpy.float64'>
# 009 cool                                <class 'numpy.float64'>
# 010 fans                                <class 'numpy.float64'>
# 011 funny                               <class 'numpy.float64'>
# 012 user_review_count                   <class 'numpy.float64'>
# 013 useful                              <class 'numpy.float64'>
# 014 seniority                           <class 'numpy.float64'>
# 015 nb_friends                          <class 'numpy.float64'>
# 016 categories                          <class 'str'>
# 017 is_open                             <class 'numpy.float64'>
# 018 latitude                            <class 'numpy.float64'>
# 019 longitude                           <class 'numpy.float64'>
# 020 postal_code                         <class 'str'>
# 021 business_review_count               <class 'numpy.float64'>
# 022 stars                               <class 'numpy.float64'>
# 023 RestaurantsPriceRange2              <class 'numpy.float64'>
# 024 RestaurantsAttire                   <class 'numpy.float64'>
# 025 RestaurantsGoodForGroups            <class 'numpy.float64'>
# 026 GoodForKids                         <class 'numpy.float64'>
# 027 RestaurantsReservations             <class 'numpy.float64'>
# 028 Alcohol                             <class 'numpy.float64'>
# 029 Caters                              <class 'numpy.float64'>
# 030 NoiseLevel                          <class 'numpy.float64'>
# 031 HasTV                               <class 'numpy.float64'>
# 032 BikeParking                         <class 'numpy.float64'>
# 033 RestaurantsDelivery                 <class 'numpy.float64'>
# 034 WiFi                                <class 'numpy.float64'>
# 035 OutdoorSeating                      <class 'numpy.float64'>
# 036 RestaurantsTakeOut                  <class 'numpy.float64'>
# 037 GoodForMeal_dessert                 <class 'numpy.float64'>
# 038 GoodForMeal_latenight               <class 'numpy.float64'>
# 039 GoodForMeal_lunch                   <class 'numpy.float64'>
# 040 GoodForMeal_dinner                  <class 'numpy.float64'>
# 041 GoodForMeal_brunch                  <class 'numpy.float64'>
# 042 GoodForMeal_breakfast               <class 'numpy.float64'>
# 043 BusinessParking_garage              <class 'numpy.float64'>
# 044 BusinessParking_street              <class 'numpy.float64'>
# 045 BusinessParking_validated           <class 'numpy.float64'>
# 046 BusinessParking_lot                 <class 'numpy.float64'>
# 047 BusinessParking_valet               <class 'numpy.float64'>
# 048 Ambience_romantic                   <class 'numpy.float64'>
# 049 Ambience_intimate                   <class 'numpy.float64'>
# 050 Ambience_classy                     <class 'numpy.float64'>
# 051 Ambience_hipster                    <class 'numpy.float64'>
# 052 Ambience_divey                      <class 'numpy.float64'>
# 053 Ambience_touristy                   <class 'numpy.float64'>
# 054 Ambience_trendy                     <class 'numpy.float64'>
# 055 Ambience_upscale                    <class 'numpy.float64'>
# 056 Ambience_casual                     <class 'numpy.float64'>
# 057 BusinessAcceptsCreditCards          <class 'numpy.float64'>
# 058 GoodForDancing                      <class 'numpy.float64'>
# 059 HappyHour                           <class 'numpy.float64'>
# 060 ByAppointmentOnly                   <class 'numpy.float64'>
# 061 WheelchairAccessible                <class 'numpy.float64'>
# 062 HairSpecializesIn_straightperms     <class 'numpy.float64'>
# 063 HairSpecializesIn_coloring          <class 'numpy.float64'>
# 064 HairSpecializesIn_extensions        <class 'numpy.float64'>
# 065 HairSpecializesIn_africanamerican   <class 'numpy.float64'>
# 066 HairSpecializesIn_curly             <class 'numpy.float64'>
# 067 HairSpecializesIn_kids              <class 'numpy.float64'>
# 068 HairSpecializesIn_perms             <class 'numpy.float64'>
# 069 HairSpecializesIn_asian             <class 'numpy.float64'>
# 070 BusinessAcceptsBitcoin              <class 'numpy.float64'>
# 071 DogsAllowed                         <class 'numpy.float64'>
# 072 CoatCheck                           <class 'numpy.float64'>
# 073 Smoking                             <class 'numpy.float64'>
# 074 RestaurantsTableService             <class 'numpy.float64'>
# 075 DriveThru                           <class 'numpy.float64'>
# 076 AcceptsInsurance                    <class 'numpy.float64'>
# 077 BYOBCorkage                         <class 'numpy.float64'>
# 078 BusinessParking                     <class 'numpy.float64'>
# 079 Music_dj                            <class 'numpy.float64'>
# 080 Music_background_music              <class 'numpy.float64'>
# 081 Music_no_music                      <class 'numpy.float64'>
# 082 Music_jukebox                       <class 'numpy.float64'>
# 083 Music_live                          <class 'numpy.float64'>
# 084 Music_video                         <class 'numpy.float64'>
# 085 Music_karaoke                       <class 'numpy.float64'>
# 086 BestNights_monday                   <class 'numpy.float64'>
# 087 BestNights_tuesday                  <class 'numpy.float64'>
# 088 BestNights_friday                   <class 'numpy.float64'>
# 089 BestNights_wednesday                <class 'numpy.float64'>
# 090 BestNights_thursday                 <class 'numpy.float64'>
# 091 BestNights_sunday                   <class 'numpy.float64'>
# 092 BestNights_saturday                 <class 'numpy.float64'>
# 093 Corkage                             <class 'numpy.float64'>
# 094 Ambience                            <class 'numpy.float64'>
# 095 Music                               <class 'numpy.float64'>
# 096 AgesAllowed                         <class 'numpy.float64'>
# 097 BYOB                                <class 'numpy.float64'>
# 098 GoodForMeal                         <class 'numpy.float64'>
# 099 DietaryRestrictions_dairy-free      <class 'numpy.float64'>
# 100 DietaryRestrictions_gluten-free     <class 'numpy.float64'>
# 101 DietaryRestrictions_vegan           <class 'numpy.float64'>
# 102 DietaryRestrictions_kosher          <class 'numpy.float64'>
# 103 DietaryRestrictions_halal           <class 'numpy.float64'>
# 104 DietaryRestrictions_soy-free        <class 'numpy.float64'>
# 105 DietaryRestrictions_vegetarian      <class 'numpy.float64'>
# 106 BestNights                          <class 'numpy.float64'>
# 107 HairSpecializesIn                   <class 'numpy.float64'>
# 108 Open24Hours                         <class 'numpy.float64'>
# 109 DietaryRestrictions                 <class 'numpy.float64'>
# 110 RestaurantsCounterService           <class 'numpy.float64'>
# 111 Monday                              <class 'str'>
# 112 Tuesday                             <class 'str'>
# 113 Wednesday                           <class 'str'>
# 114 Thursday                            <class 'str'>
# 115 Friday                              <class 'str'>
# 116 Saturday                            <class 'str'>
# 117 Sunday                              <class 'str'>

# %%
nb = len(df)
NAs = dict()
for i in range(len(df.columns)):
    NAs[df.columns[i]] = sum(pd.isna(df[df.columns[i]]))*100/nb
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NAs[key]))
# Out:
# NA for DietaryRestrictions                : 99.988399%
# NA for HairSpecializesIn                  : 99.988244%
# NA for BestNights                         : 99.985322%
# NA for GoodForMeal                        : 99.945104%
# NA for Open24Hours                        : 99.879089%
# NA for RestaurantsCounterService          : 99.847877%
# NA for Ambience                           : 99.847224%
# NA for DietaryRestrictions_dairy-free     : 99.846433%
# NA for DietaryRestrictions_gluten-free    : 99.846433%
# NA for DietaryRestrictions_vegan          : 99.846433%
# NA for DietaryRestrictions_kosher         : 99.846433%
# NA for DietaryRestrictions_halal          : 99.846433%
# NA for DietaryRestrictions_soy-free       : 99.846433%
# NA for DietaryRestrictions_vegetarian     : 99.846433%
# NA for HairSpecializesIn_straightperms    : 99.692076%
# NA for HairSpecializesIn_africanamerican  : 99.692076%
# NA for HairSpecializesIn_asian            : 99.692076%
# NA for HairSpecializesIn_coloring         : 99.658183%
# NA for HairSpecializesIn_extensions       : 99.658183%
# NA for HairSpecializesIn_curly            : 99.658183%
# NA for HairSpecializesIn_kids             : 99.658183%
# NA for HairSpecializesIn_perms            : 99.658183%
# NA for Music                              : 99.647613%
# NA for BYOB                               : 99.638951%
# NA for AgesAllowed                        : 99.574688%
# NA for BusinessParking                    : 99.312344%
# NA for AcceptsInsurance                   : 97.853795%
# NA for Corkage                            : 95.835255%
# NA for DriveThru                          : 94.799561%
# NA for BYOBCorkage                        : 92.652719%
# NA for Smoking                            : 92.062652%
# NA for CoatCheck                          : 92.049916%
# NA for HappyHour                          : 89.197785%
# NA for Music_no_music                     : 89.135087%
# NA for DogsAllowed                        : 88.847288%
# NA for BestNights_monday                  : 88.505059%
# NA for BestNights_tuesday                 : 88.505059%
# NA for BestNights_friday                  : 88.505059%
# NA for BestNights_wednesday               : 88.505059%
# NA for BestNights_thursday                : 88.505059%
# NA for BestNights_sunday                  : 88.505059%
# NA for BestNights_saturday                : 88.505059%
# NA for Music_background_music             : 88.472781%
# NA for Music_video                        : 88.469946%
# NA for Music_karaoke                      : 88.463655%
# NA for Music_jukebox                      : 88.429711%
# NA for Music_live                         : 88.367992%
# NA for GoodForDancing                     : 88.089664%
# NA for Music_dj                           : 87.147553%
# NA for BusinessAcceptsBitcoin             : 85.337012%
# NA for ByAppointmentOnly                  : 83.406762%
# NA for WheelchairAccessible               : 76.948519%
# NA for RestaurantsTableService            : 67.977435%
# NA for GoodForMeal_dessert                : 42.575704%
# NA for GoodForMeal_latenight              : 42.575704%
# NA for GoodForMeal_lunch                  : 42.575704%
# NA for GoodForMeal_dinner                 : 42.575704%
# NA for GoodForMeal_breakfast              : 42.575704%
# NA for GoodForMeal_brunch                 : 42.575395%
# NA for Ambience_divey                     : 36.533337%
# NA for RestaurantsAttire                  : 34.793384%
# NA for NoiseLevel                         : 34.305734%
# NA for Caters                             : 34.089881%
# NA for Ambience_hipster                   : 33.029248%
# NA for Ambience_upscale                   : 32.987620%
# NA for Ambience_romantic                  : 32.958763%
# NA for Ambience_intimate                  : 32.958763%
# NA for Ambience_classy                    : 32.958763%
# NA for Ambience_touristy                  : 32.958763%
# NA for Ambience_trendy                    : 32.958763%
# NA for Ambience_casual                    : 32.958763%
# NA for HasTV                              : 32.842149%
# NA for RestaurantsReservations            : 32.776563%
# NA for RestaurantsDelivery                : 32.548954%
# NA for Alcohol                            : 31.816199%
# NA for RestaurantsGoodForGroups           : 31.554010%
# NA for OutdoorSeating                     : 30.058835%
# NA for WiFi                               : 28.942447%
# NA for RestaurantsTakeOut                 : 28.607161%
# NA for GoodForKids                        : 27.251390%
# NA for BikeParking                        : 17.749569%
# NA for Sunday                             : 16.650694%
# NA for BusinessAcceptsCreditCards         : 15.696329%
# NA for BusinessParking_validated          : 14.298467%
# NA for BusinessParking_street             : 14.298312%
# NA for BusinessParking_lot                : 14.298312%
# NA for BusinessParking_valet              : 14.298020%
# NA for BusinessParking_garage             : 14.296920%
# NA for RestaurantsPriceRange2             : 12.735059%
# NA for Monday                             : 6.555471%
# NA for Saturday                           : 4.161049%
# NA for Tuesday                            : 2.646676%
# NA for Wednesday                          : 1.367561%
# NA for Thursday                           : 0.773918%
# NA for Friday                             : 0.607942%
# NA for review_id                          : 0.000000%
# NA for business_id                        : 0.000000%
# NA for user_id                            : 0.000000%
# NA for label                              : 0.000000%
# NA for average_stars                      : 0.000000%
# NA for compliment_cool                    : 0.000000%
# NA for compliment_funny                   : 0.000000%
# NA for compliment_note                    : 0.000000%
# NA for compliment_plain                   : 0.000000%
# NA for cool                               : 0.000000%
# NA for fans                               : 0.000000%
# NA for funny                              : 0.000000%
# NA for user_review_count                  : 0.000000%
# NA for useful                             : 0.000000%
# NA for seniority                          : 0.000000%
# NA for nb_friends                         : 0.000000%
# NA for categories                         : 0.000000%
# NA for is_open                            : 0.000000%
# NA for latitude                           : 0.000000%
# NA for longitude                          : 0.000000%
# NA for postal_code                        : 0.000000%
# NA for business_review_count              : 0.000000%
# NA for stars                              : 0.000000%

# %% [markdown]
# # Save Pikle

# %%
df_no_na.sample(frac=0.001, random_state=1).to_pickle("/home/nicolasbievre/sample_yelp_data.pkl")

# %%
df.to_pickle("/home/nicolasbievre/yelp_data.pkl")

# %% [markdown]
# # Fill na

# %% [markdown]
# Use fill_na_v2.py code to create a new df without na

# %% [markdown]
# # Split Train Test Val

# %%
import random

# %%
df = pd.read_pickle('../data/yelp_data_no_na.pkl')

# %%
# Get unique businesses and users
bs = df.business_id.unique()
us = df.user_id.unique()

random.seed(0)
random.shuffle(bs)
random.shuffle(us)

# Define split (train, valid, test) on the separate businesses and users
us_split = [0.205, 0.438]
bs_split = [0.205, 0.438]


"""
random.seed(0)
random.shuffle(bs)
random.shuffle(us)

# Define split (train, valid, test) on the separate businesses and users
us_split = [0.805, 0.93]
bs_split = [0.405, 0.63]



random.seed(42)
random.shuffle(bs)
random.shuffle(us)

# Define split (train, valid, test) on the separate businesses and users
us_split = [0.755, 0.93]
bs_split = [0.305, 0.53]
"""

# Split users and businesses separately
bs_split = np.split(bs, [int(bs_split[0]*len(bs)), int(bs_split[1]*len(bs))])
us_split = np.split(us, [int(us_split[0]*len(us)), int(us_split[1]*len(us))])

# %%
df['dataset'] = 'null'

# %%
# Get observations where user and business are in the correct split
df.loc[(df.business_id.isin(bs_split[0])) & (df.user_id.isin(us_split[0])), 'dataset'] = 'test'
df.loc[(df.business_id.isin(bs_split[1])) & (df.user_id.isin(us_split[1])), 'dataset'] = 'validation'
df.loc[(df.business_id.isin(bs_split[2])) & (df.user_id.isin(us_split[2])), 'dataset'] = 'train'

# %%
print('='*80)
print('RAW REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df)
pos_reviews = sum(df['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,.0f}'.format(nb_reviews))
print('Positive reviews: {:,.0f} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,.0f} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print('='*80)

print('REVIEWS DATASET AFTER SPLIT DESCRIPTION')
nb_reviews = len(df[df['dataset'] != 'null'])
pos_reviews = sum(df[df['dataset'] != 'null']['label'])
neg_revews = nb_reviews - pos_reviews
train_reviews = len(df[df['dataset'] == 'train'])
validation_reviews = len(df[df['dataset'] == 'validation'])
test_reviews = len(df[df['dataset'] == 'test'])

print('Total reviews: {:,.0f} - {:.2f}% of total reviews'.format(nb_reviews, 100*nb_reviews/len(df)))
print('Positive reviews: {:,.0f} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,.0f} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print()
print('Train reviews: {:,.0f} ({:.2f}%)'.format(train_reviews, 100*train_reviews/nb_reviews))
print('Validation reviews: {:,.0f} ({:.2f}%)'.format(validation_reviews, 100*validation_reviews/nb_reviews))
print('Test reviews: {:,.0f} ({:.2f}%)'.format(test_reviews, 100*test_reviews/nb_reviews))
print('='*80)

print('TRAIN REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df[df['dataset'] == 'train'])
pos_reviews = sum(df[df['dataset'] == 'train']['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,.0f}'.format(nb_reviews))
print('Positive reviews: {:,.0f} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,.0f} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print('='*80)

print('VALIDATION REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df[df['dataset'] == 'validation'])
pos_reviews = sum(df[df['dataset'] == 'validation']['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,.0f}'.format(nb_reviews))
print('Positive reviews: {:,.0f} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,.0f} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print('='*80)

print('TEST REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df[df['dataset'] == 'test'])
pos_reviews = sum(df[df['dataset'] == 'test']['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,.0f}'.format(nb_reviews))
print('Positive reviews: {:,.0f} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,.0f} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
# Out:
# ================================================================================
# RAW REVIEWS DATASET DESCRIPTION
# Total reviews: 5,818,316
# Positive reviews: 2,575,404 (44.26%)
# Negative reviews: 3,242,912 (55.74%)
# ================================================================================
# REVIEWS DATASET AFTER SPLIT DESCRIPTION
# Total reviews: 2,396,428 - 41.19% of total reviews
# Positive reviews: 1,062,242 (44.33%)
# Negative reviews: 1,334,186 (55.67%)
#
# Train reviews: 1,833,733 (76.52%)
# Validation reviews: 316,097 (13.19%)
# Test reviews: 246,598 (10.29%)
# ================================================================================
# TRAIN REVIEWS DATASET DESCRIPTION
# Total reviews: 1,833,733
# Positive reviews: 814,117 (44.40%)
# Negative reviews: 1,019,616 (55.60%)
# ================================================================================
# VALIDATION REVIEWS DATASET DESCRIPTION
# Total reviews: 316,097
# Positive reviews: 139,478 (44.13%)
# Negative reviews: 176,619 (55.87%)
# ================================================================================
# TEST REVIEWS DATASET DESCRIPTION
# Total reviews: 246,598
# Positive reviews: 108,647 (44.06%)
# Negative reviews: 137,951 (55.94%)

# %% [markdown]
# # Categories

# %%
import re
def extract_group(category):
    try:
        return re.findall(r'^([^,]*?),.*', str(category), re.DOTALL)[0].strip()
    except IndexError:
        return category

# %%
df['group_categories'] = df['categories'].apply(extract_group)

# %%
for i, k in enumerate(sorted(set(df['group_categories'].values))):
    print(i, k)
# Out:
# 0 3D Printing
# 1 ATV Rentals/Tours
# 2 Acai Bowls
# 3 Accessories
# 4 Accountants
# 5 Acne Treatment
# 6 Active Life
# 7 Acupuncture
# 8 Addiction Medicine
# 9 Adult
# 10 Adult Education
# 11 Adult Entertainment
# 12 Advertising
# 13 Aerial Fitness
# 14 Aerial Tours
# 15 Aestheticians
# 16 Afghan
# 17 African
# 18 Air Duct Cleaning
# 19 Aircraft Dealers
# 20 Aircraft Repairs
# 21 Airlines
# 22 Airport Lounges
# 23 Airport Shuttles
# 24 Airport Terminals
# 25 Airports
# 26 Airsoft
# 27 Allergists
# 28 Alternative Medicine
# 29 Amateur Sports Teams
# 30 American (New)
# 31 American (Traditional)
# 32 Amusement Parks
# 33 Anesthesiologists
# 34 Animal Assisted Therapy
# 35 Animal Shelters
# 36 Antiques
# 37 Apartments
# 38 Appliances
# 39 Appliances & Repair
# 40 Appraisal Services
# 41 Aquarium Services
# 42 Aquariums
# 43 Arabian
# 44 Arcades
# 45 Archery
# 46 Architects
# 47 Argentine
# 48 Armenian
# 49 Art Classes
# 50 Art Galleries
# 51 Art Museums
# 52 Art Restoration
# 53 Art Schools
# 54 Art Space Rentals
# 55 Art Supplies
# 56 Artificial Turf
# 57 Arts & Crafts
# 58 Arts & Entertainment
# 59 Asian Fusion
# 60 Assisted Living Facilities
# 61 Attraction Farms
# 62 Auction Houses
# 63 Audio/Visual Equipment Rental
# 64 Audiologist
# 65 Australian
# 66 Austrian
# 67 Auto Customization
# 68 Auto Detailing
# 69 Auto Electric Services
# 70 Auto Glass Services
# 71 Auto Insurance
# BusinessParking_valet
# BusinessParking_validated
# ByAppointmentOnly
# Caters
# CoatCheck
# Corkage
# DietaryRestrictions
# DietaryRestrictions_dairy-free
# DietaryRestrictions_gluten-free
# DietaryRestrictions_halal
# DietaryRestrictions_kosher
# DietaryRestrictions_soy-free
# DietaryRestrictions_vegan
# DietaryRestrictions_vegetarian
# DogsAllowed
# DriveThru
# Friday
# GoodForDancing
# GoodForKids
# GoodForMeal
# GoodForMeal_breakfast
# GoodForMeal_brunch
# GoodForMeal_dessert
# GoodForMeal_dinner
# GoodForMeal_latenight
# GoodForMeal_lunch
# HairSpecializesIn
# HairSpecializesIn_africanamerican
# HairSpecializesIn_asian
# HairSpecializesIn_coloring
# HairSpecializesIn_curly
# HairSpecializesIn_extensions
# HairSpecializesIn_kids
# HairSpecializesIn_perms
# HairSpecializesIn_straightperms
# HappyHour
# HasTV
# Monday
# Music
# Music_background_music
# Music_dj
# Music_jukebox
# Music_karaoke
# Music_live
# Music_no_music
# Music_video
# NoiseLevel
# Open24Hours
# OutdoorSeating
# RestaurantsAttire
# RestaurantsCounterService
# RestaurantsDelivery
# RestaurantsGoodForGroups
# RestaurantsPriceRange2
# RestaurantsReservations
# RestaurantsTableService
# RestaurantsTakeOut
# Saturday
# Smoking
# Sunday
# Thursday
# Tuesday
# Wednesday
# WheelchairAccessible
# WiFi
# average_stars
# business_id
# business_review_count
# categories
# compliment_cool
# compliment_funny
# compliment_note
# compliment_plain
# cool
# dataset
# fans
# funny
# group_categories
# is_open
# label
# latitude
# longitude
# nb_friends
# postal_code
# review_id
# seniority
# stars
# useful
# user_id
# user_review_count

# %%
category_mapping = {}
for i, key in enumerate(set(df['group_categories'].values)):
    category_mapping[key] = i

# %%
category_mapping
# Out:
# {'Physical Therapy': 0,
#  'Religious Items': 1,
#  'Departments of Motor Vehicles': 2,
#  'Computers': 3,
#  'Live/Raw Food': 4,
#  'Indian': 5,
#  'Hakka': 6,
#  'Doctors': 7,
#  'Trains': 8,
#  'Shopping Centers': 9,
#  'Breweries': 10,
#  'Parenting Classes': 11,
#  'Dance Clubs': 12,
#  'Hydrotherapy': 13,
#  'Cannabis Clinics': 14,
#  'Personal Injury Law': 15,
#  'Bed & Breakfast': 16,
#  'Synagogues': 17,
#  'Beer Bar': 18,
#  'Nutritionists': 19,
#  'Oxygen Bars': 20,
#  'Orthotics': 21,
#  'Hybrid Car Repair': 22,
#  'Piano Services': 23,
#  'Restaurant Supplies': 24,
#  'Local Flavor': 25,
#  'Pharmacy': 26,
#  'Basque': 27,
#  'Cabaret': 28,
#  'Tabletop Games': 29,
#  'Alternative Medicine': 30,
#  'Massage Schools': 31,
#  'Soul Food': 32,
#  'Hair Loss Centers': 33,
#  'Hair Salons': 34,
#  'Pest Control': 35,
#  'Moroccan': 36,
#  'Allergists': 37,
#  'Bankruptcy Law': 38,
#  'Swiss Food': 39,
#  'Parking': 40,
#  'Pop-up Shops': 41,
#  'Private Tutors': 42,
#  'Ice Cream & Frozen Yogurt': 43,
#  'Lebanese': 44,
#  'Fish & Chips': 45,
#  'Lounges': 46,
#  'Mortgage Lenders': 47,
#  'Iberian': 48,
#  'Auction Houses': 49,
#  'Pan Asian': 50,
#  'Stucco Services': 51,
#  'Retina Specialists': 52,
#  'Boat Repair': 53,
#  'Videos & Video Game Rental': 54,
#  'Hawaiian': 55,
#  'Singaporean': 56,
#  'Roadside Assistance': 57,
#  'Breakfast & Brunch': 58,
#  'Furniture Repair': 59,
#  'Trampoline Parks': 60,
#  'Storefront Clinics': 61,
#  'Scavenger Hunts': 62,
#  'Painters': 63,
#  'Grocery': 64,
#  'Cremation Services': 65,
#  'Furniture Reupholstery': 66,
#  'Video Game Stores': 67,
#  'Macarons': 68,
#  'Airsoft': 69,
#  'Pretzels': 70,
#  'Boot Camps': 71,
#  'Gift Shops': 72,
#  'Title Loans': 73,
#  'Town Car Service': 74,
#  'Spray Tanning': 75,
#  'Caribbean': 76,
#  'Airport Lounges': 77,
#  'Safe Stores': 78,
#  'Bookkeepers': 79,
#  'Adult Entertainment': 80,
#  'Officiants': 81,
#  'Internet Cafes': 82,
#  'Apartments': 83,
#  'Walking Tours': 84,
#  'Fingerprinting': 85,
#  'Financial Services': 86,
#  'Gelato': 87,
#  'Brewing Supplies': 88,
#  'Brewpubs': 89,
#  'Ethnic Grocery': 90,
#  'Campgrounds': 91,
#  'Home & Rental Insurance': 92,
#  'Court Reporters': 93,
#  'Vitamins & Supplements': 94,
#  'Keys & Locksmiths': 95,
#  'Tiling': 96,
#  'Food Trucks': 97,
#  'Piano Stores': 98,
#  'Insulation Installation': 99,
#  'Nail Salons': 100,
#  'Hostels': 101,
#  'Cantonese': 102,
#  'Pick Your Own Farms': 103,
#  'Butcher': 104,
#  'Food Delivery Services': 105,
#  'Eyelash Service': 106,
#  'Guitar Stores': 107,
#  'Fireplace Services': 108,
#  'Skate Parks': 109,
#  'Livestock Feed & Supply': 110,
#  'Hunting & Fishing Supplies': 111,
#  'Fertility': 112,
#  'Desserts': 113,
#  'Tours': 114,
#  'Auto Detailing': 115,
#  'Indonesian': 116,
#  'Irish Pub': 117,
#  'Masonry/Concrete': 118,
#  'Insurance': 119,
#  "Women's Clothing": 120,
#  'Public Relations': 121,
#  'Mobility Equipment Sales & Services': 122,
#  'Personal Care Services': 123,
#  'Public Markets': 124,
#  'British': 125,
#  'Recording & Rehearsal Studios': 126,
#  'Accountants': 127,
#  'Wedding Planning': 128,
#  'Speech Therapists': 129,
#  'Tennis': 130,
#  'Summer Camps': 131,
#  'Knitting Supplies': 132,
#  'Wine Tasting Classes': 133,
#  'Environmental Abatement': 134,
#  'Cosmetic Surgeons': 135,
#  'Printing Services': 136,
#  'Dermatologists': 137,
#  'Sporting Goods': 138,
#  'Music Venues': 139,
#  'Professional Services': 140,
#  'Police Departments': 141,
#  'Neurologist': 142,
#  'Laser Eye Surgery/Lasik': 143,
#  'Mailbox Centers': 144,
#  'Holiday Decorations': 145,
#  'Garage Door Services': 146,
#  'Austrian': 147,
#  'Travel Services': 148,
#  'Estheticians': 149,
#  'Saunas': 150,
#  'Bike Repair/Maintenance': 151,
#  'Pool Halls': 152,
#  'Go Karts': 153,
#  'Cryotherapy': 154,
#  'Preschools': 155,
#  'Bail Bondsmen': 156,
#  'Sewing & Alterations': 157,
#  'Cosmetic Dentists': 158,
#  'Slovakian': 159,
#  'Nurse Practitioner': 160,
#  'Carpet Installation': 161,
#  'Wedding Chapels': 162,
#  'Asian Fusion': 163,
#  'Tanning': 164,
#  'Fast Food': 165,
#  'Ethiopian': 166,
#  'Motorsport Vehicle Dealers': 167,
#  'Mobile Home Parks': 168,
#  'Donuts': 169,
#  'Cigar Bars': 170,
#  'Cannabis Collective': 171,
#  'Formal Wear': 172,
#  'Pub Food': 173,
#  'Cideries': 174,
#  'Golf Cart Rentals': 175,
#  'Sunglasses': 176,
#  'Health Coach': 177,
#  'Hotels & Travel': 178,
#  'Shutters': 179,
#  'Watch Repair': 180,
#  'University Housing': 181,
#  'Career Counseling': 182,
#  'Doulas': 183,
#  'Mobile Phone Repair': 184,
#  'Event Photography': 185,
#  'Sandwiches': 186,
#  'Hiking': 187,
#  'Registration Services': 188,
#  'Kickboxing': 189,
#  'Artificial Turf': 190,
#  'Home Decor': 191,
#  'Acai Bowls': 192,
#  'Performing Arts': 193,
#  'Windshield Installation & Repair': 194,
#  'Condominiums': 195,
#  'Donairs': 196,
#  'Pubs': 197,
#  'Jazz & Blues': 198,
#  'Door Sales/Installation': 199,
#  'Montessori Schools': 200,
#  '3D Printing': 201,
#  'Home Services': 202,
#  'Filipino': 203,
#  'Makeup Artists': 204,
#  'Racing Experience': 205,
#  'Dim Sum': 206,
#  'Wholesale Stores': 207,
#  'Beauty & Spas': 208,
#  'Swimwear': 209,
#  'Tableware': 210,
#  'Television Service Providers': 211,
#  'Airport Shuttles': 212,
#  'Persian/Iranian': 213,
#  'IV Hydration': 214,
#  'Cannabis Dispensaries': 215,
#  'Bookbinding': 216,
#  'Scuba Diving': 217,
#  'Hot Dogs': 218,
#  'Paint Stores': 219,
#  'Paint & Sip': 220,
#  'Waterproofing': 221,
#  'Retirement Homes': 222,
#  'Mosques': 223,
#  'Mini Golf': 224,
#  'Barbeque': 225,
#  'Poutineries': 226,
#  'Packing Services': 227,
#  'Payroll Services': 228,
#  'Tiki Bars': 229,
#  'Bartenders': 230,
#  'Herbal Shops': 231,
#  'Bubble Tea': 232,
#  'Sex Therapists': 233,
#  'Party Bike Rentals': 234,
#  'Print Media': 235,
#  'Mattresses': 236,
#  'Educational Services': 237,
#  'Powder Coating': 238,
#  'German': 239,
#  'Beer Tours': 240,
#  'Memory Care': 241,
#  'Smog Check Stations': 242,
#  'Hair Stylists': 243,
#  'Product Design': 244,
#  'Tires': 245,
#  'ATV Rentals/Tours': 246,
#  'Vinyl Records': 247,
#  'Thrift Stores': 248,
#  'Marinas': 249,
#  'Sleep Specialists': 250,
#  'Lice Services': 251,
#  'Waxing': 252,
#  'Batting Cages': 253,
#  'Firewood': 254,
#  'Diagnostic Services': 255,
#  'Movers': 256,
#  'Portuguese': 257,
#  'Golf': 258,
#  'Pet Training': 259,
#  'Musical Instruments & Teachers': 260,
#  'Water Heater Installation/Repair': 261,
#  'Internet Service Providers': 262,
#  'Florists': 263,
#  'Paddleboarding': 264,
#  'Latin American': 265,
#  'Irrigation': 266,
#  'Cajun/Creole': 267,
#  'Water Stores': 268,
#  'Employment Agencies': 269,
#  'DUI Law': 270,
#  'Fitness & Instruction': 271,
#  'Reflexology': 272,
#  'Screen Printing/T-Shirt Printing': 273,
#  'Belgian': 274,
#  'Security Services': 275,
#  'Fondue': 276,
#  'Lakes': 277,
#  'Distilleries': 278,
#  'Recreation Centers': 279,
#  'Greek': 280,
#  'Piercing': 281,
#  'Sugar Shacks': 282,
#  'Bartending Schools': 283,
#  'Engraving': 284,
#  'Body Contouring': 285,
#  'Cultural Center': 286,
#  'Pulmonologist': 287,
#  'Erotic Massage': 288,
#  'Flea Markets': 289,
#  'Interval Training Gyms': 290,
#  'Firearm Training': 291,
#  'Wigs': 292,
#  'Bike Shop': 293,
#  'Vegetarian': 294,
#  'Syrian': 295,
#  'Hotels': 296,
#  'Shaved Snow': 297,
#  'Speakeasies': 298,
#  'Bounce House Rentals': 299,
#  'Roof Inspectors': 300,
#  'Commercial Truck Repair': 301,
#  'Mobile Phones': 302,
#  'Personal Chefs': 303,
#  'Car Dealers': 304,
#  'Clock Repair': 305,
#  'Car Auctions': 306,
#  'Car Window Tinting': 307,
#  'Pet Sitting': 308,
#  'Teeth Whitening': 309,
#  'Golf Equipment': 310,
#  'Pakistani': 311,
#  'Home Health Care': 312,
#  'American (Traditional)': 313,
#  'Outlet Stores': 314,
#  'Karate': 315,
#  'IT Services & Computer Repair': 316,
#  'Cinema': 317,
#  "Men's Clothing": 318,
#  'Shaved Ice': 319,
#  'Lawn Services': 320,
#  'Pop-Up Restaurants': 321,
#  'Bicycles': 322,
#  'Nightlife': 323,
#  'Archery': 324,
#  'Car Buyers': 325,
#  'Aerial Fitness': 326,
#  'Brasseries': 327,
#  'Transportation': 328,
#  'Radiologists': 329,
#  'RV Parks': 330,
#  'Wine Bars': 331,
#  'Noodles': 332,
#  'Kids Activities': 333,
#  'Auto Security': 334,
#  'Beer Gardens': 335,
#  'Public Services & Government': 336,
#  'Motorcycle Rental': 337,
#  'Sri Lankan': 338,
#  'Commissioned Artists': 339,
#  'Churches': 340,
#  'Puerto Rican': 341,
#  'Opera & Ballet': 342,
#  'Personal Shopping': 343,
#  'LAN Centers': 344,
#  'Immigration Law': 345,
#  'Handyman': 346,
#  'Air Duct Cleaning': 347,
#  'Screen Printing': 348,
#  'Endocrinologists': 349,
#  'Interior Design': 350,
#  'Banks & Credit Unions': 351,
#  'Bistros': 352,
#  'Arabian': 353,
#  'Motorsport Vehicle Repairs': 354,
#  'Kosher': 355,
#  'Oral Surgeons': 356,
#  'Notaries': 357,
#  'Tanning Beds': 358,
#  'Hair Removal': 359,
#  'Historical Tours': 360,
#  'Cafeteria': 361,
#  'Religious Schools': 362,
#  'Water Parks': 363,
#  'Head Shops': 364,
#  'Gymnastics': 365,
#  'Music Production Services': 366,
#  'Smokehouse': 367,
#  'Wholesalers': 368,
#  'Landmarks & Historical Buildings': 369,
#  'Anesthesiologists': 370,
#  'Musicians': 371,
#  'Appraisal Services': 372,
#  'Pole Dancing Classes': 373,
#  'Safety Equipment': 374,
#  'Venezuelan': 375,
#  'Car Brokers': 376,
#  'Czech/Slovakian': 377,
#  'Tex-Mex': 378,
#  'Real Estate Agents': 379,
#  'Halotherapy': 380,
#  'Professional Sports Teams': 381,
#  'Financial Advising': 382,
#  'Ramen': 383,
#  'Skate Shops': 384,
#  'Aquariums': 385,
#  'Ophthalmologists': 386,
#  'Structural Engineers': 387,
#  'Golf Cart Dealers': 388,
#  'Foundation Repair': 389,
#  'Flooring': 390,
#  'Farmers Market': 391,
#  'Bespoke Clothing': 392,
#  'Cosmetology Schools': 393,
#  'Horseback Riding': 394,
#  'Community Gardens': 395,
#  'Medical Transportation': 396,
#  'Building Supplies': 397,
#  'Sports Clubs': 398,
#  'Tacos': 399,
#  'Counseling & Mental Health': 400,
#  'Swimming Pools': 401,
#  'Tree Services': 402,
#  'Paint-Your-Own Pottery': 403,
#  'Auto Electric Services': 404,
#  'Barbers': 405,
#  'Home & Garden': 406,
#  'Motorcycle Gear': 407,
#  'Haunted Houses': 408,
#  'Argentine': 409,
#  'Couriers & Delivery Services': 410,
#  'Reunion': 411,
#  'Signmaking': 412,
#  'Boat Dealers': 413,
#  'Teacher Supplies': 414,
#  'Perfume': 415,
#  'Flowers & Gifts': 416,
#  'Chiropractors': 417,
#  'Taekwondo': 418,
#  'Landscaping': 419,
#  'Estate Liquidation': 420,
#  'Colleges & Universities': 421,
#  'Optometrists': 422,
#  'Vehicle Shipping': 423,
#  'Life Insurance': 424,
#  'Carpenters': 425,
#  'Fire Protection Services': 426,
#  'Baby Gear & Furniture': 427,
#  'Junkyards': 428,
#  'Aircraft Dealers': 429,
#  'Party Bus Rentals': 430,
#  'Italian': 431,
#  'Sports Wear': 432,
#  'Pet Services': 433,
#  'Taiwanese': 434,
#  'Brazilian Jiu-jitsu': 435,
#  'Siding': 436,
#  'Packing Supplies': 437,
#  'Childbirth Education': 438,
#  'Russian': 439,
#  'Photo Booth Rentals': 440,
#  'Circuit Training Gyms': 441,
#  'Private Investigation': 442,
#  'Medical Cannabis Referrals': 443,
#  'Korean': 444,
#  'Cooking Schools': 445,
#  'Homeowner Association': 446,
#  'Home Automation': 447,
#  'Beach Equipment Rentals': 448,
#  'New Mexican Cuisine': 449,
#  'Baseball Fields': 450,
#  'Pets': 451,
#  'RV Dealers': 452,
#  'Indoor Landscaping': 453,
#  'Obstetricians & Gynecologists': 454,
#  'Meditation Centers': 455,
#  'Ethnic Food': 456,
#  'South African': 457,
#  'Local Fish Stores': 458,
#  'Specialty Food': 459,
#  'Naturopathic/Holistic': 460,
#  'Scandinavian': 461,
#  'Kebab': 462,
#  'Scottish': 463,
#  'Party Supplies': 464,
#  'Arcades': 465,
#  'Themed Cafes': 466,
#  'Special Education': 467,
#  'Attraction Farms': 468,
#  'Talent Agencies': 469,
#  'Dietitians': 470,
#  'Grout Services': 471,
#  'Estate Planning Law': 472,
#  'Resorts': 473,
#  'Pressure Washers': 474,
#  'Middle Schools & High Schools': 475,
#  'Specialty Schools': 476,
#  'Assisted Living Facilities': 477,
#  'Basketball Courts': 478,
#  'Contractors': 479,
#  'Cheesesteaks': 480,
#  'Supper Clubs': 481,
#  'Wraps': 482,
#  'Pet Cremation Services': 483,
#  'Airport Terminals': 484,
#  'Ziplining': 485,
#  'Hungarian': 486,
#  'Advertising': 487,
#  'Aestheticians': 488,
#  'Amusement Parks': 489,
#  'Teppanyaki': 490,
#  'Periodontists': 491,
#  'Jewelry Repair': 492,
#  'Currency Exchange': 493,
#  'Cocktail Bars': 494,
#  'African': 495,
#  'Windows Installation': 496,
#  'Web Design': 497,
#  'Wildlife Control': 498,
#  'Uniforms': 499,
#  'Ski Resorts': 500,
#  'Art Museums': 501,
#  'Damage Restoration': 502,
#  'Toy Stores': 503,
#  'Steakhouses': 504,
#  'Drive-In Theater': 505,
#  'Plastic Surgeons': 506,
#  'Surf Shop': 507,
#  'Haitian': 508,
#  'Watches': 509,
#  'Magicians': 510,
#  'Urologists': 511,
#  'Auto Repair': 512,
#  'Investing': 513,
#  'Trainers': 514,
#  'Laundry Services': 515,
#  'Plumbing': 516,
#  'Dog Parks': 517,
#  'Auto Upholstery': 518,
#  'Excavation Services': 519,
#  'Badminton': 520,
#  'Massage': 521,
#  'Knife Sharpening': 522,
#  'Delis': 523,
#  'Towing': 524,
#  'CPR Classes': 525,
#  'Bubble Soccer': 526,
#  'Laundromat': 527,
#  'Propane': 528,
#  'Olive Oil': 529,
#  'Izakaya': 530,
#  'Dive Shops': 531,
#  'Boat Charters': 532,
#  'Audio/Visual Equipment Rental': 533,
#  'Kitchen & Bath': 534,
#  'Refinishing Services': 535,
#  'Libraries': 536,
#  'Photographers': 537,
#  'Wine Tasting Room': 538,
#  'Car Rental': 539,
#  'Float Spa': 540,
#  'Bars': 541,
#  'Emergency Rooms': 542,
#  'Food': 543,
#  'Gardeners': 544,
#  'Health Markets': 545,
#  'Hong Kong Style Cafe': 546,
#  'Challenge Courses': 547,
#  'Coffee & Tea': 548,
#  'Botanical Gardens': 549,
#  'Check Cashing/Pay-day Loans': 550,
#  'Urgent Care': 551,
#  'Religious Organizations': 552,
#  'Decks & Railing': 553,
#  'Real Estate Law': 554,
#  'Mobile Home Dealers': 555,
#  'Japanese Curry': 556,
#  'Museums': 557,
#  'Seafood': 558,
#  'Cambodian': 559,
#  'Arts & Crafts': 560,
#  'Vacation Rentals': 561,
#  'Martial Arts': 562,
#  'Threading Services': 563,
#  'Concept Shops': 564,
#  'Sandblasting': 565,
#  'Prosthodontists': 566,
#  'Snow Removal': 567,
#  'RV Repair': 568,
#  'Boudoir Photography': 569,
#  'Champagne Bars': 570,
#  'Hookah Bars': 571,
#  'Mortuary Services': 572,
#  'Luggage': 573,
#  'Pet Groomers': 574,
#  'Hot Tub & Pool': 575,
#  'Customized Merchandise': 576,
#  'Furniture Assembly': 577,
#  'Irish': 578,
#  'Septic Services': 579,
#  'Empanadas': 580,
#  'French': 581,
#  'Burmese': 582,
#  'Trailer Rental': 583,
#  'Appliances': 584,
#  'Beverage Store': 585,
#  'Cuban': 586,
#  'Used Bookstore': 587,
#  'Art Supplies': 588,
#  'Venues & Event Spaces': 589,
#  'Art Classes': 590,
#  'Concierge Medicine': 591,
#  'Food Stands': 592,
#  'Hardware Stores': 593,
#  'Blow Dry/Out Services': 594,
#  'Music & DVDs': 595,
#  'Cardio Classes': 596,
#  'Dance Studios': 597,
#  'Tui Na': 598,
#  'Aerial Tours': 599,
#  'Adult Education': 600,
#  'Surfing': 601,
#  'Arts & Entertainment': 602,
#  'Education': 603,
#  'Art Galleries': 604,
#  'Trophy Shops': 605,
#  'Hair Extensions': 606,
#  'Auto Customization': 607,
#  'Preventive Medicine': 608,
#  'Diagnostic Imaging': 609,
#  'Comfort Food': 610,
#  'Passport & Visa Services': 611,
#  'Dominican': 612,
#  'Restaurants': 613,
#  'Wills': 614,
#  'Sushi Bars': 615,
#  'Australian': 616,
#  'Leather Goods': 617,
#  'Coffee & Tea Supplies': 618,
#  'Lactation Services': 619,
#  'Seafood Markets': 620,
#  'Window Washing': 621,
#  'Fabric Stores': 622,
#  'Vacation Rental Agents': 623,
#  'Lighting Stores': 624,
#  'Home Inspectors': 625,
#  'Tapas Bars': 626,
#  'Mediterranean': 627,
#  'American (New)': 628,
#  'Solar Panel Cleaning': 629,
#  'Tattoo Removal': 630,
#  'Photography Stores & Services': 631,
#  'Egyptian': 632,
#  'Family Practice': 633,
#  'Business Consulting': 634,
#  'Buffets': 635,
#  'Sports Medicine': 636,
#  'Post Offices': 637,
#  'Cardiologists': 638,
#  'Gutter Services': 639,
#  'Musical Instrument Services': 640,
#  'Environmental Testing': 641,
#  'Boating': 642,
#  'Gunsmith': 643,
#  'Organic Stores': 644,
#  'Street Vendors': 645,
#  'Books': 646,
#  'Property Management': 647,
#  'Health Retreats': 648,
#  'Process Servers': 649,
#  'Electronics': 650,
#  'Aircraft Repairs': 651,
#  'Whiskey Bars': 652,
#  'Bakeries': 653,
#  'Videographers': 654,
#  'Transmission Repair': 655,
#  'Utilities': 656,
#  'Veterinarians': 657,
#  'Drones': 658,
#  'CSA': 659,
#  'Tobacco Shops': 660,
#  'Party Characters': 661,
#  'Disc Golf': 662,
#  'Criminal Defense Law': 663,
#  'Acne Treatment': 664,
#  'Clothing Rental': 665,
#  'Art Space Rentals': 666,
#  'Valet Services': 667,
#  'Japanese': 668,
#  'Motorcycle Repair': 669,
#  'Newspapers & Magazines': 670,
#  'Walk-in Clinics': 671,
#  'Behavior Analysts': 672,
#  'Medical Supplies': 673,
#  'Mexican': 674,
#  'Shredding Services': 675,
#  'Strip Clubs': 676,
#  'Emergency Medicine': 677,
#  'Psychics': 678,
#  'Swimming Lessons/Schools': 679,
#  'Electricians': 680,
#  'Golf Equipment Shops': 681,
#  'Bowling': 682,
#  'Dry Cleaning': 683,
#  'Office Cleaning': 684,
#  'Addiction Medicine': 685,
#  'Pizza': 686,
#  'Chocolatiers & Shops': 687,
#  'Mobile Phone Accessories': 688,
#  'Honduran': 689,
#  'Chimney Sweeps': 690,
#  'Gastroenterologist': 691,
#  'Furniture Stores': 692,
#  'Trailer Repair': 693,
#  'Backshop': 694,
#  'Auto Loan Providers': 695,
#  'Colonics': 696,
#  'Food Tours': 697,
#  'Bagels': 698,
#  'Wineries': 699,
#  'Real Estate Services': 700,
#  'Water Purification Services': 701,
#  'Department Stores': 702,
#  'Vegan': 703,
#  'Candy Stores': 704,
#  'Weight Loss Centers': 705,
#  'Trailer Dealers': 706,
#  'Midwives': 707,
#  'Chicken Wings': 708,
#  'Party & Event Planning': 709,
#  'Real Estate': 710,
#  'Gerontologists': 711,
#  'Dinner Theater': 712,
#  'Balloon Services': 713,
#  'Grilling Equipment': 714,
#  'Drugstores': 715,
#  'Marketing': 716,
#  'Vehicle Wraps': 717,
#  'Tutoring Centers': 718,
#  'Muay Thai': 719,
#  'Custom Cakes': 720,
#  'Massage Therapy': 721,
#  'Hydro-jetting': 722,
#  'Rheumatologists': 723,
#  'Mass Media': 724,
#  'Fireworks': 725,
#  'Auto Insurance': 726,
#  'Metal Fabricators': 727,
#  'Pet Boarding': 728,
#  'Gluten-Free': 729,
#  'Vietnamese': 730,
#  'Tai Chi': 731,
#  'Squash': 732,
#  'Mauritius': 733,
#  'Lingerie': 734,
#  'Karaoke': 735,
#  'Home Energy Auditors': 736,
#  'Skydiving': 737,
#  'Surgeons': 738,
#  'Sports Psychologists': 739,
#  'Skin Care': 740,
#  'Cycling Classes': 741,
#  'Hearing Aid Providers': 742,
#  'Sailing': 743,
#  'Beach Bars': 744,
#  'Playgrounds': 745,
#  'Nurseries & Gardening': 746,
#  'Gay Bars': 747,
#  'Poke': 748,
#  'Home Staging': 749,
#  'Linens': 750,
#  'Cupcakes': 751,
#  'Emergency Pet Hospital': 752,
#  'Ayurveda': 753,
#  'Food Court': 754,
#  'Electronics Repair': 755,
#  'Zoos': 756,
#  'Ukrainian': 757,
#  'Art Restoration': 758,
#  'Tax Services': 759,
#  'Stadiums & Arenas': 760,
#  'Shades & Blinds': 761,
#  'Cooking Classes': 762,
#  'Polish': 763,
#  'Elementary Schools': 764,
#  'Nanny Services': 765,
#  'Cannabis Tours': 766,
#  'Sledding': 767,
#  'Day Camps': 768,
#  'Heating & Air Conditioning/HVAC': 769,
#  'Rehabilitation Center': 770,
#  'Cabinetry': 771,
#  'Supernatural Readings': 772,
#  'Turkish': 773,
#  'Self Storage': 774,
#  'General Dentistry': 775,
#  'Guns & Ammo': 776,
#  'Lighting Fixtures & Equipment': 777,
#  'Escape Games': 778,
#  'Paintball': 779,
#  'Driving Schools': 780,
#  'House Sitters': 781,
#  'Editorial Services': 782,
#  'Audiologist': 783,
#  'Office Equipment': 784,
#  'Rock Climbing': 785,
#  'TV Mounting': 786,
#  'Mountain Biking': 787,
#  'Crane Services': 788,
#  'Parks': 789,
#  'Endodontists': 790,
#  'Cards & Stationery': 791,
#  'Yelp Events': 792,
#  'Tea Rooms': 793,
#  'Floral Designers': 794,
#  'Oil Change Stations': 795,
#  'Shanghainese': 796,
#  'Aquarium Services': 797,
#  'Home Cleaning': 798,
#  'Maternity Wear': 799,
#  'Honey': 800,
#  'DIY Auto Shop': 801,
#  'Caterers': 802,
#  'Lawyers': 803,
#  'Recycling Center': 804,
#  'Tattoo': 805,
#  'Patisserie/Cake Shop': 806,
#  'Community Service/Non-Profit': 807,
#  'Chinese Martial Arts': 808,
#  'Fruits & Veggies': 809,
#  'Skilled Nursing': 810,
#  'Free Diving': 811,
#  'Casinos': 812,
#  'Beaches': 813,
#  'Patio Coverings': 814,
#  'Demolition Services': 815,
#  'Do-It-Yourself Food': 816,
#  'Boxing': 817,
#  'Soup': 818,
#  'Kids Hair Salons': 819,
#  'Chinese': 820,
#  'Burgers': 821,
#  'Pet Photography': 822,
#  'Interlock Systems': 823,
#  'Nudist': 824,
#  'Barre Classes': 825,
#  'Afghan': 826,
#  'Junk Removal & Hauling': 827,
#  'Permanent Makeup': 828,
#  'Modern European': 829,
#  'Internal Medicine': 830,
#  'Coffeeshops': 831,
#  'Appliances & Repair': 832,
#  'Cheese Shops': 833,
#  'Brazilian': 834,
#  'Auto Parts & Supplies': 835,
#  'Video/Film Production': 836,
#  'Peruvian': 837,
#  'Life Coach': 838,
#  'Dog Walkers': 839,
#  'Gemstones & Minerals': 840,
#  'Business Law': 841,
#  'Planetarium': 842,
#  'Clowns': 843,
#  'Pool Cleaners': 844,
#  'Orthopedists': 845,
#  'Outdoor Gear': 846,
#  'Beer': 847,
#  'Limos': 848,
#  'Used Car Dealers': 849,
#  'EV Charging Stations': 850,
#  'International': 851,
#  'Service Stations': 852,
#  'Soccer': 853,
#  'Adult': 854,
#  'Health Insurance Offices': 855,
#  'Oncologist': 856,
#  'Neurotologists': 857,
#  'Farm Equipment Repair': 858,
#  'Farming Equipment': 859,
#  'Prenatal/Perinatal Care': 860,
#  'Carpeting': 861,
#  'Fur Clothing': 862,
#  'Soba': 863,
#  'Chicken Shop': 864,
#  'Auto Glass Services': 865,
#  'Fences & Gates': 866,
#  'Traditional Chinese Medicine': 867,
#  'Homeopathic': 868,
#  'Country Clubs': 869,
#  'Axe Throwing': 870,
#  'Dumpster Rental': 871,
#  'Bookstores': 872,
#  'Hobby Shops': 873,
#  'Candle Stores': 874,
#  'Pet Stores': 875,
#  'Gas Stations': 876,
#  'Graphic Design': 877,
#  'Osteopathic Physicians': 878,
#  'Hot Air Balloons': 879,
#  'Szechuan': 880,
#  'Salad': 881,
#  'Ticket Sales': 882,
#  'Embroidery & Crochet': 883,
#  'Occupational Therapy': 884,
#  'Pain Management': 885,
#  'Convenience Stores': 886,
#  'Gold Buyers': 887,
#  'Eyebrow Services': 888,
#  'Machine & Tool Rental': 889,
#  'Waffles': 890,
#  'Outdoor Furniture Stores': 891,
#  'Telecommunications': 892,
#  'Landscape Architects': 893,
#  'Car Stereo Installation': 894,
#  'Eyewear & Opticians': 895,
#  'Eatertainment': 896,
#  'Roofing': 897,
#  'Laser Tag': 898,
#  'Dental Hygienists': 899,
#  'Elder Care Planning': 900,
#  'Gun/Rifle Ranges': 901,
#  'Fire Departments': 902,
#  'Test Preparation': 903,
#  'Donation Center': 904,
#  'Bridal': 905,
#  'Mongolian': 906,
#  'Laotian': 907,
#  'Henna Artists': 908,
#  'Hats': 909,
#  'Art Schools': 910,
#  'Jewelry': 911,
#  'Spin Classes': 912,
#  'Cosmetics & Beauty Supply': 913,
#  'Bar Crawl': 914,
#  'Home Network Installation': 915,
#  'Vascular Medicine': 916,
#  'Horse Boarding': 917,
#  'Wheel & Rim Repair': 918,
#  'Falafel': 919,
#  'Spiritual Shop': 920,
#  'Mediators': 921,
#  'Team Building Activities': 922,
#  'Rafting/Kayaking': 923,
#  'Spine Surgeons': 924,
#  'Rugs': 925,
#  'Hot Pot': 926,
#  'Event Planning & Services': 927,
#  'Medical Spas': 928,
#  'Social Clubs': 929,
#  'Souvenir Shops': 930,
#  'Creperies': 931,
#  'Day Spas': 932,
#  'Gyms': 933,
#  "Children's Clothing": 934,
#  'International Grocery': 935,
#  'Animal Assisted Therapy': 936,
#  'Middle Eastern': 937,
#  'Shopping': 938,
#  'Motorcycle Dealers': 939,
#  'Fitness/Exercise Equipment': 940,
#  'Pilates': 941,
#  'Mortgage Brokers': 942,
#  'Battery Stores': 943,
#  'Automotive': 944,
#  'Prosthetics': 945,
#  'Television Stations': 946,
#  'Salvadoran': 947,
#  "Men's Hair Salons": 948,
#  'Child Care & Day Care': 949,
#  'Sugaring': 950,
#  'Debt Relief Services': 951,
#  'Countertop Installation': 952,
#  'Fishing': 953,
#  'Accessories': 954,
#  'Face Painting': 955,
#  'Self-defense Classes': 956,
#  'Pediatric Dentists': 957,
#  'Podiatrists': 958,
#  'Horse Racing': 959,
#  'Discount Store': 960,
#  'Home Organization': 961,
#  'RV Rental': 962,
#  'Cheerleading': 963,
#  'Bikes': 964,
#  'Local Services': 965,
#  'Buddhist Temples': 966,
#  'Hydroponics': 967,
#  'Fashion': 968,
#  'Private Jet Charter': 969,
#  'Herbs & Spices': 970,
#  'Furniture Rental': 971,
#  'Hospice': 972,
#  'Christmas Trees': 973,
#  'Ice Delivery': 974,
#  'Infectious Disease Specialists': 975,
#  'Climbing': 976,
#  'Costumes': 977,
#  'Security Systems': 978,
#  'Skating Rinks': 979,
#  'Himalayan/Nepalese': 980,
#  'Tapas/Small Plates': 981,
#  'Plus Size Fashion': 982,
#  'Dive Bars': 983,
#  'Meat Shops': 984,
#  'Animal Shelters': 985,
#  'Commercial Real Estate': 986,
#  'Malaysian': 987,
#  'Party Equipment Rentals': 988,
#  'Blood & Plasma Donation Centers': 989,
#  'Home Developers': 990,
#  'Antiques': 991,
#  'Ear Nose & Throat': 992,
#  'Carpet Cleaning': 993,
#  'Golf Lessons': 994,
#  'Amateur Sports Teams': 995,
#  'Diners': 996,
#  'Personal Assistants': 997,
#  'Indoor Playcentre': 998,
#  'Truck Rental': 999,
#  ...}

# %%
df['group_categories'] = df['group_categories'].apply(lambda x: np.double(category_mapping[x]))

# %%
df[['group_categories']].head(n=100)
# Out:
#     group_categories
# 0              932.0
# 1              932.0
# 2              932.0
# 3              932.0
# 4              932.0
# ..               ...
# 95             102.0
# 96             102.0
# 97             102.0
# 98             102.0
# 99             102.0
#
# [100 rows x 1 columns]

# %%
train = df[df['dataset'] == 'train'].copy()
val = df[df['dataset'] == 'validation'].copy()
test = df[df['dataset'] == 'test'].copy()

# %%
train.drop(['dataset', 'review_id', 'business_id', 'user_id', 
            'postal_code', 'stars', 'categories',
            'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
           axis=1, inplace=True)
val.drop(['dataset', 'review_id', 'business_id', 'user_id', 
            'postal_code', 'stars', 'categories',
            'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
           axis=1, inplace=True)
test.drop(['dataset', 'review_id', 'business_id', 'user_id', 
            'postal_code', 'stars', 'categories',
            'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
           axis=1, inplace=True)

# %%
train.dtypes
# Out:
# label                        float64
# average_stars                float64
# compliment_cool              float64
# compliment_funny             float64
# compliment_note              float64
#                               ...
# HairSpecializesIn            float64
# Open24Hours                  float64
# DietaryRestrictions          float64
# RestaurantsCounterService    float64
# group_categories             float64
# Length: 106, dtype: object

# %%
train.to_pickle("../data/train.pkl")
val.to_pickle("../data/val.pkl")
test.to_pickle("../data/test.pkl")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
file_na = '/home/nicolasbievre/yelp_data.pkl'
df_no_na = pd.read_pickle(file_na)
df_no_na.dtypes
# Out:
# review_id                           object
# business_id                         object
# user_id                             object
# label                              float64
# average_stars                      float64
# compliment_cool                    float64
# compliment_funny                   float64
# compliment_note                    float64
# compliment_plain                   float64
# cool                               float64
# fans                               float64
# funny                              float64
# user_review_count                  float64
# useful                             float64
# seniority                          float64
# nb_friends                         float64
# categories                          object
# is_open                            float64
# latitude                           float64
# longitude                          float64
# postal_code                         object
# business_review_count              float64
# stars                              float64
# RestaurantsPriceRange2             float64
# RestaurantsAttire                  float64
# RestaurantsGoodForGroups           float64
# GoodForKids                        float64
# RestaurantsReservations            float64
# Alcohol                            float64
# Caters                             float64
#                                     ...
# BestNights_wednesday               float64
# BestNights_thursday                float64
# BestNights_sunday                  float64
# BestNights_saturday                float64
# Corkage                            float64
# Ambience                           float64
# Music                              float64
# AgesAllowed                        float64
# BYOB                               float64
# GoodForMeal                        float64
# DietaryRestrictions_dairy-free     float64
# DietaryRestrictions_gluten-free    float64
# DietaryRestrictions_vegan          float64
# DietaryRestrictions_kosher         float64
# DietaryRestrictions_halal          float64
# DietaryRestrictions_soy-free       float64
# DietaryRestrictions_vegetarian     float64
# BestNights                         float64
# HairSpecializesIn                  float64
# Open24Hours                        float64
# DietaryRestrictions                float64
# RestaurantsCounterService          float64
# Monday                              object
# Tuesday                             object
# Wednesday                           object
# Thursday                            object
# Friday                              object
# Saturday                            object
# Sunday                              object
# group_categories                    object
# Length: 119, dtype: object

# %%
categories = list(set(df_no_na['categories']))

# %%
print(len(list(set(df_no_na['group_categories']))))
print(len(list(set(df_no_na['categories']))))
#  Tabletop Games
#  Tableware
#  Tacos
#  Taekwondo
#  Tai Chi
#  Taiwanese
#  Talent Agencies
#  Tanning
#  Tanning Beds
#  Tapas Bars
#  Tapas/Small Plates
#  Tasting Classes
#  Tattoo
#  Tattoo Removal
#  Tax Services
#  Taxis
#  Tea Rooms
#  Teacher Supplies
#  Team Building Activities
#  Teeth Whitening
#  Telecommunications
#  Television Service Providers
#  Tennis
#  Teppanyaki
#  Test Preparation
#  Tex-Mex
#  Thai
#  Themed Cafes
#  Threading Services
#  Thrift Stores
#  Ticket Sales
#  Tickets
#  Tiki Bars
#  Tiling
#  Tires
#  Title Loans
#  Tobacco Shops
#  Tours
#  Towing
#  Toy Stores
#  Traditional Chinese Medicine
#  Trailer Dealers
#  Trailer Rental
#  Trailer Repair
#  Trainers
#  Trains
#  Trampoline Parks
#  Translation Services
#  Transmission Repair
#  Transportation
#  Travel Services
#  Tree Services
#  Trinidadian
#  Trophy Shops
#  Truck Rental
#  Trusts
#  Tubing
#  Tui Na
#  Turkish
#  Tuscan
#  Tutoring Centers
#  Ukrainian
#  Ultrasound Imaging Centers
#  Uniforms
#  University Housing
#  Urgent Care
#  Urologists
#  Used
#  Used Bookstore
#  Used Car Dealers
#  Utilities
#  Vacation Rental Agents
#  Vacation Rentals
#  Valet Services
#  Vape Shops
#  Vascular Medicine
#  Vegan
#  Vegetarian
#  Vehicle Shipping
#  Vehicle Wraps
#  Venezuelan
#  Venues & Event Spaces
#  Veterinarians
#  Video Game Stores
#  Video/Film Production
#  Videographers
#  Videos & Video Game Rental
#  Vietnamese
#  Vintage & Consignment
#  Vinyl Records
#  Virtual Reality Centers
#  Visitor Centers
#  Vitamins & Supplements
#  Vocal Coach
#  Vocational & Technical School
#  Waffles
#  Walk-in Clinics
#  Walking Tours
#  Wallpapering
#  Watch Repair
#  Watches
#  Water Delivery
#  Water Heater Installation/Repair
#  Water Parks
#  Water Purification Services
#  Water Stores
#  Waterproofing
#  Waxing
#  Web Design
#  Wedding Chapels
#  Wedding Planning
#  Weight Loss Centers
#  Wheel & Rim Repair
#  Whiskey Bars
#  Wholesale Stores
#  Wholesalers
#  Wigs
#  Wildlife Control
#  Window Washing
#  Windows Installation
#  Windshield Installation & Repair
#  Wine & Spirits
#  Wine Bars
#  Wine Tasting Classes
#  Wine Tasting Room
#  Wine Tours
#  Wineries
#  Women's Clothing
#  Wraps
#  Yelp Events
#  Yoga
#  Zoos
# ATV Rentals/Tours, Active Life
# Active Life
# Active Life, Amateur Sports Teams
# Active Life, Amusement Parks
# Active Life, Aquariums
# Active Life, Archery
# Active Life, Badminton
# Active Life, Batting Cages
# Active Life, Beaches
# Active Life, Bike Rentals
# Active Life, Bowling
# Active Life, Challenge Courses
# Active Life, Climbing
# Active Life, Cycling Classes
# Active Life, Diving
# Active Life, Escape Games
# Active Life, Fitness & Instruction
# Active Life, Go Karts
# Active Life, Golf
# Active Life, Gun/Rifle Ranges
# Active Life, Gymnastics
# Active Life, Hiking
# Active Life, Horseback Riding
# Beauty & Spas, Skin Care
# Beauty & Spas, Tanning
# Beauty & Spas, Tattoo
# Bed & Breakfast, Hotels & Travel
# Belgian, Restaurants
# Bike Repair/Maintenance, Local Services
# Bistros, Restaurants
# Blood & Plasma Donation Centers, Health & Medical
# Boating, Active Life
# Body Shops, Automotive
# Bookbinding, Local Services
# Botanical Gardens, Arts & Entertainment
# Bowling, Active Life
# Brasseries, Restaurants
# Brazilian, Restaurants
# Breakfast & Brunch, Restaurants
# Breweries, Food
# Brewing Supplies, Shopping
# Bridal, Shopping
# British, Restaurants
# Bubble Tea, Food
# Buffets, Restaurants
# Building Supplies, Home Services
# Burgers, Restaurants
# Burmese, Restaurants
# Butcher, Food
# CSA, Food
# Cabinetry, Home Services
# Cafes, Restaurants
# Cafeteria, Restaurants
# Cajun/Creole, Restaurants
# Cambodian, Restaurants
# Canadian (New), Restaurants
# Cannabis Clinics, Health & Medical
# Cannabis Dispensaries, Shopping
# Car Auctions, Automotive
# Car Dealers, Automotive
# Car Rental, Hotels & Travel
# Car Stereo Installation, Automotive
# Car Wash, Automotive
# Caribbean, Restaurants
# Carpet Cleaning, Local Services
# Casinos, Arts & Entertainment
# Caterers, Event Planning & Services
# Challenge Courses, Active Life
# Cheesesteaks, Restaurants
# Chicken Shop, Restaurants
# Chicken Wings, Restaurants
# Child Care & Day Care, Local Services
# Chimney Sweeps, Home Services
# Chinese, Restaurants
# Chiropractors, Health & Medical
# Churches, Religious Organizations
# Cinema, Arts & Entertainment
# Climbing, Active Life
# Coffee & Tea, Food
# Colleges & Universities, Education
# Colonics, Health & Medical
# Comedy Clubs, Nightlife
# Comfort Food, Restaurants
# Community Service/Non-Profit, Local Services
# Computers, Shopping
# Contractors, Home Services
# Convenience Stores, Food
# Counseling & Mental Health, Health & Medical
# Couriers & Delivery Services, Local Services
# Creperies, Restaurants
# Cryotherapy, Health & Medical
# Cuban, Restaurants
# Customized Merchandise, Shopping
# Cycling Classes, Active Life
# DJs, Event Planning & Services
# Damage Restoration, Home Services
# Dance Clubs, Nightlife
# Day Spas, Beauty & Spas
# Delicatessen, Food
# Delis, Restaurants
# Dentists, Health & Medical
# Desserts, Food
# Diagnostic Services, Health & Medical
# Diners, Restaurants
# Discount Store, Shopping
# Distilleries, Food
# Do-It-Yourself Food, Food
# Doctors, Health & Medical
# Donairs, Food
# Donuts, Food
# Door Sales/Installation, Home Services
# Drugstores, Shopping
# EV Charging Stations, Automotive
# Education, Colleges & Universities
# Electricians, Home Services
# Electronics Repair, Local Services
# Electronics, Shopping
# Environmental Testing, Local Services
# Escape Games, Active Life
# Ethiopian, Restaurants
# Event Planning & Services, Boat Charters
# Event Planning & Services, Caterers
# Event Planning & Services, DJs
# Event Planning & Services, Party & Event Planning
# Event Planning & Services, Party Equipment Rentals
# Event Planning & Services, Party Supplies
# Event Planning & Services, Photo Booth Rentals
# Event Planning & Services, Photographers
# Event Planning & Services, Professional Services
# Event Planning & Services, Venues & Event Spaces
# Event Planning & Services, Videographers
# Eyelash Service, Beauty & Spas
# Eyewear & Opticians, Shopping
# Farmers Market, Food
# Farming Equipment, Shopping
# Fashion, Shopping
# Fast Food, Restaurants
# Fences & Gates, Home Services
# Fencing Clubs, Active Life
# Festivals, Arts & Entertainment
# Filipino, Restaurants
# Financial Services, Banks & Credit Unions
# Financial Services, Insurance
# Fingerprinting, Local Services
# Fireplace Services, Home Services
# Fireworks, Shopping
# Fish & Chips, Restaurants
# Fitness & Instruction, Active Life
# Flea Markets, Shopping
# Float Spa, Health & Medical
# Flooring, Home Services
# Flowers & Gifts, Shopping
# Fondue, Restaurants
# Food
# Food Court, Restaurants
# Food Delivery Services, Food
# Food Stands, Restaurants
# Food Trucks, Food
# Food, Bagels
# Food, Bakeries
# Food, Breweries
# Food, Bubble Tea
# Food, Butcher
# Food, Coffee & Tea
# Food, Coffee Roasteries
# Food, Convenience Stores
# Food, Delicatessen
# Food, Desserts
# Food, Distilleries
# Food, Do-It-Yourself Food
# Food, Donuts
# Food, Farmers Market
# Food, Food Delivery Services
# Food, Food Trucks
# Food, Gelato
# Food, Grocery
# Food, Ice Cream & Frozen Yogurt
# Food, International Grocery
# Food, Juice Bars & Smoothies
# Food, Organic Stores
# Food, Patisserie/Cake Shop
# Food, Poke
# Food, Pretzels
# Food, Shaved Ice
# Food, Specialty Food
# Food, Street Vendors
# Food, Tea Rooms
# French, Restaurants
# Funeral Services & Cemeteries, Local Services
# Furniture Assembly, Home Services
# Furniture Reupholstery, Local Services
# Garage Door Services, Home Services
# Gardeners, Home Services
# Gas Stations, Automotive
# Gastropubs, Restaurants
# Gelato, Food
# German, Restaurants
# Glass & Mirrors, Home Services
# Gluten-Free, Restaurants
# Go Karts, Active Life
# Golf, Active Life
# Greek, Restaurants
# Grocery, Food
# Gun/Rifle Ranges, Active Life
# Guns & Ammo, Shopping
# Gymnastics, Active Life
# Hair Removal, Beauty & Spas
# Hair Salons, Beauty & Spas
# Halal, Restaurants
# Handyman, Home Services
# Haunted Houses, Arts & Entertainment
# Hawaiian, Restaurants
# Head Shops, Shopping
# Health & Medical
# Health & Medical, Acupuncture
# Health & Medical, Blood & Plasma Donation Centers
# Health & Medical, Cannabis Clinics
# Health & Medical, Chiropractors
# Health & Medical, Colonics
# Health & Medical, Counseling & Mental Health
# Health & Medical, Cryotherapy
# Health & Medical, Dentists
# Health & Medical, Diagnostic Services
# Health & Medical, Doctors
# Health & Medical, Emergency Rooms
# Health & Medical, Float Spa
# Health & Medical, Home Health Care
# Health & Medical, Hospice
# Health & Medical, Hospitals
# Health & Medical, Lactation Services
# Health & Medical, Laser Eye Surgery/Lasik
# Health & Medical, Lice Services
# Health & Medical, Massage Therapy
# Health & Medical, Medical Centers
# Health & Medical, Medical Transportation
# Health & Medical, Midwives
# Health & Medical, Nutritionists
# Health & Medical, Occupational Therapy
# Health & Medical, Optometrists
# Health & Medical, Orthotics
# Health & Medical, Pharmacy
# Health & Medical, Physical Therapy
# Health & Medical, Reflexology
# Health & Medical, Rehabilitation Center
# Health & Medical, Reiki
# Health & Medical, Retirement Homes
# Health & Medical, Skilled Nursing
# Health & Medical, Sleep Specialists
# Health & Medical, Speech Therapists
# Health & Medical, Traditional Chinese Medicine
# Health & Medical, Urgent Care
# Health & Medical, Weight Loss Centers
# Hearing Aid Providers, Health & Medical
# Heating & Air Conditioning/HVAC, Home Services
# Hiking, Active Life
# Himalayan/Nepalese, Restaurants
# Hobby Shops, Shopping
# Home & Garden, Shopping
# Home Cleaning, Home Services
# Home Energy Auditors, Home Services
# Home Health Care, Health & Medical
# Home Inspectors, Home Services
# Home Organization, Home Services
# Home Services
# Home Services, Artificial Turf
# Home Services, Building Supplies
# Home Services, Cabinetry
# Home Services, Carpenters
# Home Services, Carpeting
# Home Services, Contractors
# Home Services, Countertop Installation
# Home Services, Damage Restoration
# Home Services, Electricians
# Home Services, Fences & Gates
# Home Services, Fire Protection Services
# Home Services, Firewood
# Home Services, Flooring
# Home Services, Furniture Assembly
# Home Services, Garage Door Services
# Home Services, Gardeners
# Home Services, Glass & Mirrors
# Home Services, Gutter Services
# Home Services, Handyman
# Home Services, Heating & Air Conditioning/HVAC
# Home Services, Home Cleaning
# Home Services, Home Inspectors
# Home Services, Home Organization
# Home Services, Home Window Tinting
# Home Services, Interior Design
# Home Services, Irrigation
# Home Services, Keys & Locksmiths
# Home Services, Landscaping
# Home Services, Lighting Fixtures & Equipment
# Home Services, Local Services
# Home Services, Masonry/Concrete
# Home Services, Movers
# Home Services, Painters
# Home Services, Plumbing
# Home Services, Pool & Hot Tub Service
# Home Services, Pool Cleaners
# Home Services, Real Estate
# Home Services, Refinishing Services
# Home Services, Roofing
# Home Services, Security Systems
# Home Services, Shades & Blinds
# Home Services, Shutters
# Home Services, Solar Installation
# Home Services, Tree Services
# Home Services, Water Heater Installation/Repair
# Home Services, Water Purification Services
# Home Services, Window Washing
# Home Services, Windows Installation
# Honduran, Restaurants
# Horseback Riding, Active Life
# Hospice, Health & Medical
# Hospitals, Health & Medical
# Hostels, Hotels & Travel
# Hot Dogs, Restaurants
# Hot Pot, Restaurants
# Hotels & Travel, Airports
# Hotels & Travel, Bed & Breakfast
# Hotels & Travel, Tours
# Hungarian, Restaurants
# Hybrid Car Repair, Automotive
# IT Services & Computer Repair, Local Services
# Ice Cream & Frozen Yogurt, Food
# Indian, Restaurants
# Indonesian, Restaurants
# Interior Design, Home Services
# International Grocery, Food
# Irish, Restaurants
# Irrigation, Home Services
# Italian, Restaurants
# Japanese, Restaurants
# Jewelry, Shopping
# Juice Bars & Smoothies, Food
# Junk Removal & Hauling, Local Services
# Karaoke, Nightlife
# Keys & Locksmiths, Home Services
# Kids Activities, Active Life
# Knitting Supplies, Shopping
# Korean, Restaurants
# Kosher, Restaurants
# Lactation Services, Health & Medical
# Landscape Architects, Home Services
# Landscaping, Home Services
# Laser Eye Surgery/Lasik, Health & Medical
# Latin American, Restaurants
# Libraries, Public Services & Government
# Lice Services, Health & Medical
# Lighting Fixtures & Equipment, Home Services
# Local Flavor
# Local Flavor, Public Services & Government
# Local Flavor, Yelp Events
# Local Services
# Local Services, Air Duct Cleaning
# Local Services, Appliances & Repair
# Local Services, Bail Bondsmen
# Local Services, Carpet Cleaning
# Local Services, Child Care & Day Care
# Local Services, Community Service/Non-Profit
# Local Services, Couriers & Delivery Services
# Local Services, Crane Services
# Local Services, Donation Center
# Local Services, Electronics Repair
# Local Services, Funeral Services & Cemeteries
# Local Services, Furniture Reupholstery
# Local Services, IT Services & Computer Repair
# Local Services, Junk Removal & Hauling
# Local Services, Mailbox Centers
# Local Services, Metal Fabricators
# Local Services, Musical Instrument Services
# Local Services, Notaries
# Local Services, Pest Control
# Local Services, Printing Services
# Local Services, Propane
# Local Services, Public Services & Government
# Local Services, Recycling Center
# Local Services, Screen Printing
# Local Services, Screen Printing/T-Shirt Printing
# Local Services, Self Storage
# Local Services, Sewing & Alterations
# Local Services, Shipping Centers
# Local Services, Shoe Repair
# Local Services, Watch Repair
# Local Services, Water Delivery
# Luggage, Shopping
# Machine Shops, Local Services
# Makeup Artists, Beauty & Spas
# Malaysian, Restaurants
# Masonry/Concrete, Home Services
# Massage Therapy, Health & Medical
# Massage, Beauty & Spas
# Medical Centers, Health & Medical
# Medical Supplies, Shopping
# Medical Transportation, Health & Medical
# Mediterranean, Restaurants
# Metal Fabricators, Local Services
# Mexican, Restaurants
# Middle Eastern, Restaurants
# Midwives, Health & Medical
# Mini Golf, Active Life
# Mobile Phones, Shopping
# Modern European, Restaurants
# Mongolian, Restaurants
# Moroccan, Restaurants
# Motorcycle Dealers, Automotive
# Motorcycle Repair, Automotive
# Movers, Home Services
# Museums, Arts & Entertainment
# Musical Instrument Services, Local Services
# Musical Instruments & Teachers, Shopping
# Nail Salons, Beauty & Spas
# Nanny Services, Local Services
# New Mexican Cuisine, Restaurants
# Nightlife
# Nightlife, Adult Entertainment
# Nightlife, Bars
# Nightlife, Comedy Clubs
# Nightlife, Dance Clubs
# Nightlife, Karaoke
# Nightlife, Pool Halls
# Nightlife, Restaurants
# Noodles, Restaurants
# Notaries, Local Services
# Nutritionists, Health & Medical
# Occupational Therapy, Health & Medical
# Office Equipment, Shopping
# Officiants, Event Planning & Services
# Oil Change Stations, Automotive
# Optometrists, Health & Medical
# Organic Stores, Food
# Outlet Stores, Shopping
# Paint & Sip, Arts & Entertainment
# Painters, Home Services
# Pakistani, Restaurants
# Parking, Automotive
# Parks, Active Life
# Party & Event Planning, Event Planning & Services
# Party Bike Rentals, Event Planning & Services
# Party Bus Rentals, Event Planning & Services
# Party Equipment Rentals, Event Planning & Services
# Party Supplies, Event Planning & Services
# Patisserie/Cake Shop, Food
# Pawn Shops, Shopping
# Performing Arts, Arts & Entertainment
# Persian/Iranian, Restaurants
# Peruvian, Restaurants
# Pest Control, Local Services
# Pet Stores, Pets
# Pets, Pet Stores
# Pets, Veterinarians
# Pharmacy, Health & Medical
# Photo Booth Rentals, Event Planning & Services
# Photographers, Event Planning & Services
# Photography Stores & Services, Shopping
# Physical Therapy, Health & Medical
# Pizza, Restaurants
# Playgrounds, Active Life
# Plumbing, Home Services
# Poke, Food
# Polish, Restaurants
# Pool & Billiards, Shopping
# Pool & Hot Tub Service, Home Services
# Pool Cleaners, Home Services
# Pool Halls, Nightlife
# Portuguese, Restaurants
# Poutineries, Restaurants
# Pretzels, Food
# Printing Services, Local Services
# Professional Services
# Professional Services, Employment Agencies
# Professional Services, Local Services
# Professional Services, Shredding Services
# Professional Services, Video/Film Production
# Propane, Local Services
# Public Markets, Shopping
# Public Services & Government, Libraries
# Public Services & Government, Local Flavor
# Public Services & Government, Post Offices
# RV Dealers, Automotive
# Rafting/Kayaking, Active Life
# Real Estate, Home Services
# Recording & Rehearsal Studios, Local Services
# Recreation Centers, Active Life
# Recycling Center, Local Services
# Reflexology, Health & Medical
# Registration Services, Automotive
# Rehabilitation Center, Health & Medical
# Religious Organizations, Churches
# Restaurants
# Restaurants, Afghan
# Restaurants, African
# Restaurants, American (New)
# Restaurants, American (Traditional)
# Restaurants, Argentine
# Restaurants, Asian Fusion
# Restaurants, Bangladeshi
# Restaurants, Barbeque
# Restaurants, Bistros
# Restaurants, Brasseries
# Restaurants, Breakfast & Brunch
# Restaurants, British
# Restaurants, Buffets
# Restaurants, Burgers
# Restaurants, Burmese
# Restaurants, Cafes
# Restaurants, Cafeteria
# Restaurants, Cajun/Creole
# Restaurants, Cambodian
# Restaurants, Canadian (New)
# Restaurants, Caribbean
# Restaurants, Cheesesteaks
# Restaurants, Chicken Shop
# Restaurants, Chicken Wings
# Restaurants, Chinese
# Restaurants, Comfort Food
# Restaurants, Creperies
# Restaurants, Cuban
# Restaurants, Czech
# Restaurants, Delis
# Restaurants, Diners
# Restaurants, Ethiopian
# Restaurants, Fast Food
# Restaurants, Filipino
# Restaurants, Fish & Chips
# Restaurants, Fondue
# Restaurants, Food
# Restaurants, Food Court
# Restaurants, Food Stands
# Restaurants, French
# Restaurants, Gastropubs
# Restaurants, German
# Restaurants, Gluten-Free
# Restaurants, Greek
# Restaurants, Hawaiian
# Restaurants, Himalayan/Nepalese
# Restaurants, Hot Dogs
# Restaurants, Hot Pot
# Restaurants, Hungarian
# Restaurants, Indian
# Restaurants, Indonesian
# Restaurants, Irish
# Restaurants, Italian
# Restaurants, Japanese
# Restaurants, Korean
# Restaurants, Kosher
# Restaurants, Latin American
# Restaurants, Malaysian
# Restaurants, Mediterranean
# Restaurants, Mexican
# Restaurants, Middle Eastern
# Restaurants, Modern European
# Restaurants, Mongolian
# Restaurants, Moroccan
# Restaurants, New Mexican Cuisine
# Restaurants, Nightlife
# Restaurants, Noodles
# Restaurants, Pakistani
# Restaurants, Pan Asian
# Restaurants, Persian/Iranian
# Restaurants, Peruvian
# Restaurants, Pizza
# Restaurants, Polish
# Restaurants, Portuguese
# Restaurants, Poutineries
# Restaurants, Russian
# Restaurants, Salad
# Restaurants, Sandwiches
# Restaurants, Seafood
# Restaurants, Soul Food
# Restaurants, Soup
# Restaurants, Southern
# Restaurants, Spanish
# Restaurants, Sri Lankan
# Restaurants, Steakhouses
# Restaurants, Sushi Bars
# Tex-Mex, Restaurants
# Thai, Restaurants
# Thrift Stores, Shopping
# Ticket Sales, Arts & Entertainment
# Tires, Automotive
# Tobacco Shops, Shopping
# Towing, Automotive
# Toy Stores, Shopping
# Trampoline Parks, Active Life
# Tree Services, Home Services
# Trophy Shops, Shopping
# Truck Rental, Automotive
# Turkish, Restaurants
# Ukrainian, Restaurants
# Uniforms, Shopping
# Urgent Care, Health & Medical
# Used Car Dealers, Automotive
# Utilities, Home Services
# Vape Shops, Shopping
# Vegan, Restaurants
# Vegetarian, Restaurants
# Vehicle Shipping, Automotive
# Venues & Event Spaces, Event Planning & Services
# Veterinarians, Pets
# Videographers, Event Planning & Services
# Vietnamese, Restaurants
# Virtual Reality Centers, Arts & Entertainment
# Vitamins & Supplements, Shopping
# Waffles, Restaurants
# Watch Repair, Local Services
# Watches, Shopping
# Water Delivery, Local Services
# Water Parks, Active Life
# Water Purification Services, Home Services
# Water Stores, Food
# Wedding Chapels, Event Planning & Services
# Wedding Planning, Event Planning & Services
# Weight Loss Centers, Health & Medical
# Wholesale Stores, Shopping
# Window Washing, Home Services
# Windows Installation, Home Services
# Yelp Events, Local Flavor
# Ziplining, Active Life
# Zoos, Active Life

# %%
df_no_na.to_pickle("/home/nicolasbievre/yelp_data.pkl")

# %%
file_na = '/home/nicolasbievre/sample_yelp_data.pkl'
df_no_na = pd.read_pickle(file_na)
nb = len(df_no_na)
NA1s = dict()
for i in range(len(df_no_na.columns)):
    NA1s[df_no_na.columns[i]] = sum(pd.isna(df_no_na[df_no_na.columns[i]]))*100/nb
    
for key in sorted(NA1s, key=NA1s.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NA1s[key]))
# Out:
# NA for HairSpecializesIn                  : 100.000000%
# NA for DietaryRestrictions                : 100.000000%
# NA for BestNights                         : 99.982812%
# NA for GoodForMeal                        : 99.914060%
# NA for Open24Hours                        : 99.914060%
# NA for DietaryRestrictions_dairy-free     : 99.879684%
# NA for DietaryRestrictions_gluten-free    : 99.879684%
# NA for DietaryRestrictions_vegan          : 99.879684%
# NA for DietaryRestrictions_kosher         : 99.879684%
# NA for DietaryRestrictions_halal          : 99.879684%
# NA for DietaryRestrictions_soy-free       : 99.879684%
# NA for DietaryRestrictions_vegetarian     : 99.879684%
# NA for Ambience                           : 99.845308%
# NA for RestaurantsCounterService          : 99.845308%
# NA for BYOB                               : 99.793744%
# NA for HairSpecializesIn_straightperms    : 99.656239%
# NA for HairSpecializesIn_africanamerican  : 99.656239%
# NA for HairSpecializesIn_asian            : 99.656239%
# NA for HairSpecializesIn_coloring         : 99.621863%
# NA for HairSpecializesIn_extensions       : 99.621863%
# NA for HairSpecializesIn_curly            : 99.621863%
# NA for HairSpecializesIn_kids             : 99.621863%
# NA for HairSpecializesIn_perms            : 99.621863%
# NA for Music                              : 99.604675%
# NA for BusinessParking                    : 99.432795%
# NA for AgesAllowed                        : 99.415607%
# NA for AcceptsInsurance                   : 98.023376%
# NA for Corkage                            : 96.132692%
# NA for DriveThru                          : 94.293572%
# NA for Smoking                            : 92.660708%
# NA for BYOBCorkage                        : 92.643520%
# NA for CoatCheck                          : 92.591956%
# NA for HappyHour                          : 89.532485%
# NA for Music_no_music                     : 89.016844%
# NA for DogsAllowed                        : 88.827776%
# NA for BestNights_monday                  : 88.621519%
# NA for BestNights_tuesday                 : 88.621519%
# NA for BestNights_friday                  : 88.621519%
# NA for BestNights_wednesday               : 88.621519%
# NA for BestNights_thursday                : 88.621519%
# NA for BestNights_sunday                  : 88.621519%
# NA for BestNights_saturday                : 88.621519%
# NA for Music_background_music             : 88.501203%
# NA for Music_video                        : 88.501203%
# NA for Music_karaoke                      : 88.501203%
# NA for Music_jukebox                      : 88.484015%
# NA for Music_live                         : 88.380887%
# NA for GoodForDancing                     : 88.191818%
# NA for Music_dj                           : 87.246476%
# NA for BusinessAcceptsBitcoin             : 85.372980%
# NA for ByAppointmentOnly                  : 83.258852%
# NA for WheelchairAccessible               : 77.311791%
# NA for RestaurantsTableService            : 67.892747%
# NA for GoodForMeal_dessert                : 42.316947%
# NA for GoodForMeal_latenight              : 42.316947%
# NA for GoodForMeal_lunch                  : 42.316947%
# NA for GoodForMeal_dinner                 : 42.316947%
# NA for GoodForMeal_brunch                 : 42.316947%
# NA for GoodForMeal_breakfast              : 42.316947%
# NA for Ambience_divey                     : 36.541767%
# NA for RestaurantsAttire                  : 34.668271%
# NA for NoiseLevel                         : 34.599519%
# NA for Caters                             : 34.358886%
# NA for Ambience_hipster                   : 33.104160%
# NA for Ambience_upscale                   : 33.052595%
# NA for Ambience_romantic                  : 33.001031%
# NA for Ambience_intimate                  : 33.001031%
# NA for Ambience_classy                    : 33.001031%
# NA for Ambience_touristy                  : 33.001031%
# NA for Ambience_trendy                    : 33.001031%
# NA for Ambience_casual                    : 33.001031%
# NA for HasTV                              : 32.932279%
# NA for RestaurantsReservations            : 32.743211%
# NA for RestaurantsDelivery                : 32.536954%
# NA for Alcohol                            : 32.176006%
# NA for RestaurantsGoodForGroups           : 31.574424%
# NA for OutdoorSeating                     : 29.975937%
# NA for WiFi                               : 28.875902%
# NA for RestaurantsTakeOut                 : 28.394637%
# NA for GoodForKids                        : 26.796150%
# NA for BikeParking                        : 17.308353%
# NA for Sunday                             : 16.758336%
# NA for BusinessAcceptsCreditCards         : 16.431763%
# NA for BusinessParking_garage             : 13.836370%
# NA for BusinessParking_street             : 13.836370%
# NA for BusinessParking_validated          : 13.836370%
# NA for BusinessParking_lot                : 13.836370%
# NA for BusinessParking_valet              : 13.836370%
# NA for RestaurantsPriceRange2             : 12.598831%
# NA for Monday                             : 6.789275%
# NA for Saturday                           : 4.090753%
# NA for Tuesday                            : 2.767274%
# NA for Wednesday                          : 1.564111%
# NA for Thursday                           : 0.739086%
# NA for Friday                             : 0.601581%
# NA for review_id                          : 0.000000%
# NA for business_id                        : 0.000000%
# NA for user_id                            : 0.000000%
# NA for label                              : 0.000000%
# NA for average_stars                      : 0.000000%
# NA for compliment_cool                    : 0.000000%
# NA for compliment_funny                   : 0.000000%
# NA for compliment_note                    : 0.000000%
# NA for compliment_plain                   : 0.000000%
# NA for cool                               : 0.000000%
# NA for fans                               : 0.000000%
# NA for funny                              : 0.000000%
# NA for user_review_count                  : 0.000000%
# NA for useful                             : 0.000000%
# NA for seniority                          : 0.000000%
# NA for nb_friends                         : 0.000000%
# NA for categories                         : 0.000000%
# NA for is_open                            : 0.000000%
# NA for latitude                           : 0.000000%
# NA for longitude                          : 0.000000%
# NA for postal_code                        : 0.000000%
# NA for business_review_count              : 0.000000%
# NA for stars                              : 0.000000%
# NA for group_categories                   : 0.000000%

# %%
file_na = '/home/nicolasbievre/yelp_data_no_na_group.pkl'
df_no_na = pd.read_pickle(file_na)
nb = len(df_no_na)
NAs = dict()
for i in range(len(df_no_na.columns)):
    NAs[df_no_na.columns[i]] = sum(pd.isna(df_no_na[df_no_na.columns[i]]))*100/nb
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NAs[key]))
# Out:
# NA for HairSpecializesIn                  : 100.000000%
# NA for DietaryRestrictions                : 100.000000%
# NA for BestNights                         : 99.982812%
# NA for GoodForMeal                        : 99.914060%
# NA for Open24Hours                        : 99.914060%
# NA for DietaryRestrictions_dairy-free     : 99.879684%
# NA for DietaryRestrictions_gluten-free    : 99.879684%
# NA for DietaryRestrictions_vegan          : 99.879684%
# NA for DietaryRestrictions_kosher         : 99.879684%
# NA for DietaryRestrictions_halal          : 99.879684%
# NA for DietaryRestrictions_soy-free       : 99.879684%
# NA for DietaryRestrictions_vegetarian     : 99.879684%
# NA for Ambience                           : 99.845308%
# NA for RestaurantsCounterService          : 99.845308%
# NA for BYOB                               : 99.793744%
# NA for HairSpecializesIn_straightperms    : 99.656239%
# NA for HairSpecializesIn_africanamerican  : 99.656239%
# NA for HairSpecializesIn_asian            : 99.656239%
# NA for HairSpecializesIn_coloring         : 99.621863%
# NA for HairSpecializesIn_extensions       : 99.621863%
# NA for HairSpecializesIn_curly            : 99.621863%
# NA for HairSpecializesIn_kids             : 99.621863%
# NA for HairSpecializesIn_perms            : 99.621863%
# NA for Music                              : 99.604675%
# NA for BusinessParking                    : 99.432795%
# NA for AgesAllowed                        : 99.415607%
# NA for AcceptsInsurance                   : 98.023376%
# NA for Corkage                            : 96.132692%
# NA for DriveThru                          : 94.293572%
# NA for Smoking                            : 92.660708%
# NA for BYOBCorkage                        : 92.643520%
# NA for CoatCheck                          : 92.591956%
# NA for HappyHour                          : 89.532485%
# NA for Music_no_music                     : 89.016844%
# NA for DogsAllowed                        : 88.827776%
# NA for BestNights_monday                  : 88.621519%
# NA for BestNights_tuesday                 : 88.621519%
# NA for BestNights_friday                  : 88.621519%
# NA for BestNights_wednesday               : 88.621519%
# NA for BestNights_thursday                : 88.621519%
# NA for BestNights_sunday                  : 88.621519%
# NA for BestNights_saturday                : 88.621519%
# NA for Music_background_music             : 88.501203%
# NA for Music_video                        : 88.501203%
# NA for Music_karaoke                      : 88.501203%
# NA for Music_jukebox                      : 88.484015%
# NA for Music_live                         : 88.380887%
# NA for GoodForDancing                     : 88.191818%
# NA for Music_dj                           : 87.246476%
# NA for BusinessAcceptsBitcoin             : 85.372980%
# NA for ByAppointmentOnly                  : 83.258852%
# NA for WheelchairAccessible               : 77.311791%
# NA for RestaurantsTableService            : 67.892747%
# NA for GoodForMeal_dessert                : 42.316947%
# NA for GoodForMeal_latenight              : 42.316947%
# NA for GoodForMeal_lunch                  : 42.316947%
# NA for GoodForMeal_dinner                 : 42.316947%
# NA for GoodForMeal_brunch                 : 42.316947%
# NA for GoodForMeal_breakfast              : 42.316947%
# NA for Ambience_divey                     : 36.541767%
# NA for RestaurantsAttire                  : 34.668271%
# NA for NoiseLevel                         : 34.599519%
# NA for Caters                             : 34.358886%
# NA for Ambience_hipster                   : 33.104160%
# NA for Ambience_upscale                   : 33.052595%
# NA for Ambience_romantic                  : 33.001031%
# NA for Ambience_intimate                  : 33.001031%
# NA for Ambience_classy                    : 33.001031%
# NA for Ambience_touristy                  : 33.001031%
# NA for Ambience_trendy                    : 33.001031%
# NA for Ambience_casual                    : 33.001031%
# NA for HasTV                              : 32.932279%
# NA for RestaurantsReservations            : 32.743211%
# NA for RestaurantsDelivery                : 32.536954%
# NA for Alcohol                            : 32.176006%
# NA for RestaurantsGoodForGroups           : 31.574424%
# NA for OutdoorSeating                     : 29.975937%
# NA for WiFi                               : 28.875902%
# NA for RestaurantsTakeOut                 : 28.394637%
# NA for GoodForKids                        : 26.796150%
# NA for BikeParking                        : 17.308353%
# NA for BusinessAcceptsCreditCards         : 16.431763%
# NA for BusinessParking_garage             : 13.836370%
# NA for BusinessParking_street             : 13.836370%
# NA for BusinessParking_validated          : 13.836370%
# NA for BusinessParking_lot                : 13.836370%
# NA for BusinessParking_valet              : 13.836370%
# NA for RestaurantsPriceRange2             : 12.598831%
# NA for Sunday                             : 3.025095%
# NA for Saturday                           : 0.687521%
# NA for Monday                             : 0.550017%
# NA for Tuesday                            : 0.189068%
# NA for Thursday                           : 0.068752%
# NA for Friday                             : 0.068752%
# NA for Wednesday                          : 0.051564%
# NA for review_id                          : 0.000000%
# NA for business_id                        : 0.000000%
# NA for user_id                            : 0.000000%
# NA for label                              : 0.000000%
# NA for average_stars                      : 0.000000%
# NA for compliment_cool                    : 0.000000%
# NA for compliment_funny                   : 0.000000%
# NA for compliment_note                    : 0.000000%
# NA for compliment_plain                   : 0.000000%
# NA for cool                               : 0.000000%
# NA for fans                               : 0.000000%
# NA for funny                              : 0.000000%
# NA for user_review_count                  : 0.000000%
# NA for useful                             : 0.000000%
# NA for seniority                          : 0.000000%
# NA for nb_friends                         : 0.000000%
# NA for categories                         : 0.000000%
# NA for is_open                            : 0.000000%
# NA for latitude                           : 0.000000%
# NA for longitude                          : 0.000000%
# NA for postal_code                        : 0.000000%
# NA for business_review_count              : 0.000000%
# NA for stars                              : 0.000000%
# NA for group_categories                   : 0.000000%

# %%
NA_delta = {key: NAs[key] - NA1s[key] for key in NAs}
for key in sorted(NA_delta, key=NA_delta.get, reverse=True):
    print('{:35s}: {:.6f}%'.format(key, NA_delta[key]))
# Out:
# review_id                          : 0.000000%
# business_id                        : 0.000000%
# user_id                            : 0.000000%
# label                              : 0.000000%
# average_stars                      : 0.000000%
# compliment_cool                    : 0.000000%
# compliment_funny                   : 0.000000%
# compliment_note                    : 0.000000%
# compliment_plain                   : 0.000000%
# cool                               : 0.000000%
# fans                               : 0.000000%
# funny                              : 0.000000%
# user_review_count                  : 0.000000%
# useful                             : 0.000000%
# seniority                          : 0.000000%
# nb_friends                         : 0.000000%
# categories                         : 0.000000%
# is_open                            : 0.000000%
# latitude                           : 0.000000%
# longitude                          : 0.000000%
# postal_code                        : 0.000000%
# business_review_count              : 0.000000%
# stars                              : 0.000000%
# RestaurantsPriceRange2             : 0.000000%
# RestaurantsAttire                  : 0.000000%
# RestaurantsGoodForGroups           : 0.000000%
# GoodForKids                        : 0.000000%
# RestaurantsReservations            : 0.000000%
# Alcohol                            : 0.000000%
# Caters                             : 0.000000%
# NoiseLevel                         : 0.000000%
# HasTV                              : 0.000000%
# BikeParking                        : 0.000000%
# RestaurantsDelivery                : 0.000000%
# WiFi                               : 0.000000%
# OutdoorSeating                     : 0.000000%
# RestaurantsTakeOut                 : 0.000000%
# GoodForMeal_dessert                : 0.000000%
# GoodForMeal_latenight              : 0.000000%
# GoodForMeal_lunch                  : 0.000000%
# GoodForMeal_dinner                 : 0.000000%
# GoodForMeal_brunch                 : 0.000000%
# GoodForMeal_breakfast              : 0.000000%
# BusinessParking_garage             : 0.000000%
# BusinessParking_street             : 0.000000%
# BusinessParking_validated          : 0.000000%
# BusinessParking_lot                : 0.000000%
# BusinessParking_valet              : 0.000000%
# Ambience_romantic                  : 0.000000%
# Ambience_intimate                  : 0.000000%
# Ambience_classy                    : 0.000000%
# Ambience_hipster                   : 0.000000%
# Ambience_divey                     : 0.000000%
# Ambience_touristy                  : 0.000000%
# Ambience_trendy                    : 0.000000%
# Ambience_upscale                   : 0.000000%
# Ambience_casual                    : 0.000000%
# BusinessAcceptsCreditCards         : 0.000000%
# GoodForDancing                     : 0.000000%
# HappyHour                          : 0.000000%
# ByAppointmentOnly                  : 0.000000%
# WheelchairAccessible               : 0.000000%
# HairSpecializesIn_straightperms    : 0.000000%
# HairSpecializesIn_coloring         : 0.000000%
# HairSpecializesIn_extensions       : 0.000000%
# HairSpecializesIn_africanamerican  : 0.000000%
# HairSpecializesIn_curly            : 0.000000%
# HairSpecializesIn_kids             : 0.000000%
# HairSpecializesIn_perms            : 0.000000%
# HairSpecializesIn_asian            : 0.000000%
# BusinessAcceptsBitcoin             : 0.000000%
# DogsAllowed                        : 0.000000%
# CoatCheck                          : 0.000000%
# Smoking                            : 0.000000%
# RestaurantsTableService            : 0.000000%
# DriveThru                          : 0.000000%
# AcceptsInsurance                   : 0.000000%
# BYOBCorkage                        : 0.000000%
# BusinessParking                    : 0.000000%
# Music_dj                           : 0.000000%
# Music_background_music             : 0.000000%
# Music_no_music                     : 0.000000%
# Music_jukebox                      : 0.000000%
# Music_live                         : 0.000000%
# Music_video                        : 0.000000%
# Music_karaoke                      : 0.000000%
# BestNights_monday                  : 0.000000%
# BestNights_tuesday                 : 0.000000%
# BestNights_friday                  : 0.000000%
# BestNights_wednesday               : 0.000000%
# BestNights_thursday                : 0.000000%
# BestNights_sunday                  : 0.000000%
# BestNights_saturday                : 0.000000%
# Corkage                            : 0.000000%
# Ambience                           : 0.000000%
# Music                              : 0.000000%
# AgesAllowed                        : 0.000000%
# BYOB                               : 0.000000%
# GoodForMeal                        : 0.000000%
# DietaryRestrictions_dairy-free     : 0.000000%
# DietaryRestrictions_gluten-free    : 0.000000%
# DietaryRestrictions_vegan          : 0.000000%
# DietaryRestrictions_kosher         : 0.000000%
# DietaryRestrictions_halal          : 0.000000%
# DietaryRestrictions_soy-free       : 0.000000%
# DietaryRestrictions_vegetarian     : 0.000000%
# BestNights                         : 0.000000%
# HairSpecializesIn                  : 0.000000%
# Open24Hours                        : 0.000000%
# DietaryRestrictions                : 0.000000%
# RestaurantsCounterService          : 0.000000%
# group_categories                   : 0.000000%
# Friday                             : -0.532829%
# Thursday                           : -0.670333%
# Wednesday                          : -1.512547%
# Tuesday                            : -2.578206%
# Saturday                           : -3.403231%
# Monday                             : -6.239257%
# Sunday                             : -13.733242%

# %% [markdown]
# # Save Final Dataset

# %%
df.to_pickle("/home/nicolasbievre/yelp_dataset.pkl")

# %% [markdown]
# # Dealing with Business Missing Values

# %%
nb = len(df)
NAs = dict()
for i in range(len(df.columns)):
    NAs[df.columns[i]] = sum(pd.isna(df[df.columns[i]]))*100/nb
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NAs[key]))
# Out:
# NA for DietaryRestrictions                : 99.988399%
# NA for HairSpecializesIn                  : 99.988244%
# NA for BestNights                         : 99.985322%
# NA for GoodForMeal                        : 99.945104%
# NA for Open24Hours                        : 99.879089%
# NA for RestaurantsCounterService          : 99.847877%
# NA for Ambience                           : 99.847224%
# NA for DietaryRestrictions_dairy-free     : 99.846433%
# NA for DietaryRestrictions_gluten-free    : 99.846433%
# NA for DietaryRestrictions_vegan          : 99.846433%
# NA for DietaryRestrictions_kosher         : 99.846433%
# NA for DietaryRestrictions_halal          : 99.846433%
# NA for DietaryRestrictions_soy-free       : 99.846433%
# NA for DietaryRestrictions_vegetarian     : 99.846433%
# NA for HairSpecializesIn_straightperms    : 99.692076%
# NA for HairSpecializesIn_africanamerican  : 99.692076%
# NA for HairSpecializesIn_asian            : 99.692076%
# NA for HairSpecializesIn_coloring         : 99.658183%
# NA for HairSpecializesIn_extensions       : 99.658183%
# NA for HairSpecializesIn_curly            : 99.658183%
# NA for HairSpecializesIn_kids             : 99.658183%
# NA for HairSpecializesIn_perms            : 99.658183%
# NA for Music                              : 99.647613%
# NA for BYOB                               : 99.638951%
# NA for AgesAllowed                        : 99.574688%
# NA for BusinessParking                    : 99.312344%
# NA for AcceptsInsurance                   : 97.853795%
# NA for Corkage                            : 95.835255%
# NA for DriveThru                          : 94.799561%
# NA for BYOBCorkage                        : 92.652719%
# NA for Smoking                            : 92.062652%
# NA for CoatCheck                          : 92.049916%
# NA for HappyHour                          : 89.197785%
# NA for Music_no_music                     : 89.135087%
# NA for DogsAllowed                        : 88.847288%
# NA for BestNights_monday                  : 88.505059%
# NA for BestNights_tuesday                 : 88.505059%
# NA for BestNights_friday                  : 88.505059%
# NA for BestNights_wednesday               : 88.505059%
# NA for BestNights_thursday                : 88.505059%
# NA for BestNights_sunday                  : 88.505059%
# NA for BestNights_saturday                : 88.505059%
# NA for Music_background_music             : 88.472781%
# NA for Music_video                        : 88.469946%
# NA for Music_karaoke                      : 88.463655%
# NA for Music_jukebox                      : 88.429711%
# NA for Music_live                         : 88.367992%
# NA for GoodForDancing                     : 88.089664%
# NA for Music_dj                           : 87.147553%
# NA for BusinessAcceptsBitcoin             : 85.337012%
# NA for ByAppointmentOnly                  : 83.406762%
# NA for WheelchairAccessible               : 76.948519%
# NA for RestaurantsTableService            : 67.977435%
# NA for GoodForMeal_dessert                : 42.575704%
# NA for GoodForMeal_latenight              : 42.575704%
# NA for GoodForMeal_lunch                  : 42.575704%
# NA for GoodForMeal_dinner                 : 42.575704%
# NA for GoodForMeal_breakfast              : 42.575704%
# NA for GoodForMeal_brunch                 : 42.575395%
# NA for Ambience_divey                     : 36.533337%
# NA for RestaurantsAttire                  : 34.793384%
# NA for NoiseLevel                         : 34.305734%
# NA for Caters                             : 34.089881%
# NA for Ambience_hipster                   : 33.029248%
# NA for Ambience_upscale                   : 32.987620%
# NA for Ambience_romantic                  : 32.958763%
# NA for Ambience_intimate                  : 32.958763%
# NA for Ambience_classy                    : 32.958763%
# NA for Ambience_touristy                  : 32.958763%
# NA for Ambience_trendy                    : 32.958763%
# NA for Ambience_casual                    : 32.958763%
# NA for HasTV                              : 32.842149%
# NA for RestaurantsReservations            : 32.776563%
# NA for RestaurantsDelivery                : 32.548954%
# NA for Alcohol                            : 31.816199%
# NA for RestaurantsGoodForGroups           : 31.554010%
# NA for OutdoorSeating                     : 30.058835%
# NA for WiFi                               : 28.942447%
# NA for RestaurantsTakeOut                 : 28.607161%
# NA for GoodForKids                        : 27.251390%
# NA for BikeParking                        : 17.749569%
# NA for BusinessAcceptsCreditCards         : 15.696329%
# NA for BusinessParking_validated          : 14.298467%
# NA for BusinessParking_street             : 14.298312%
# NA for BusinessParking_lot                : 14.298312%
# NA for BusinessParking_valet              : 14.298020%
# NA for BusinessParking_garage             : 14.296920%
# NA for RestaurantsPriceRange2             : 12.735059%
# NA for review_id                          : 0.000000%
# NA for business_id                        : 0.000000%
# NA for user_id                            : 0.000000%
# NA for label                              : 0.000000%
# NA for average_stars                      : 0.000000%
# NA for compliment_cool                    : 0.000000%
# NA for compliment_funny                   : 0.000000%
# NA for compliment_note                    : 0.000000%
# NA for compliment_plain                   : 0.000000%
# NA for cool                               : 0.000000%
# NA for fans                               : 0.000000%
# NA for funny                              : 0.000000%
# NA for user_review_count                  : 0.000000%
# NA for useful                             : 0.000000%
# NA for seniority                          : 0.000000%
# NA for nb_friends                         : 0.000000%
# NA for address                            : 0.000000%
# NA for categories                         : 0.000000%
# NA for city                               : 0.000000%
# NA for is_open                            : 0.000000%
# NA for latitude                           : 0.000000%
# NA for longitude                          : 0.000000%
# NA for name                               : 0.000000%
# NA for postal_code                        : 0.000000%
# NA for business_review_count              : 0.000000%
# NA for stars                              : 0.000000%
# NA for state                              : 0.000000%
# NA for Monday                             : 0.000000%
# NA for Tuesday                            : 0.000000%
# NA for Wednesday                          : 0.000000%
# NA for Thursday                           : 0.000000%
# NA for Friday                             : 0.000000%
# NA for Saturday                           : 0.000000%
# NA for Sunday                             : 0.000000%

# %%
categories = list(set(df['categories']))
len(categories)
# Out:
# 72081

# %%
for i, category in enumerate(categories):
    print(i, category)
    sub_df = df[df['categories'] == category]
    for i in range(len(sub_df.columns)):
        na = sum(pd.isna(sub_df[sub_df.columns[i]]))
        if na > 0:
            count = Counter(sub_df[sub_df.columns[i]])
            try:
                del count[np.nan]
            except:
                pass
            
            if count == dict():
                count = Counter(df[df.columns[i]])
                try:
                    del count[np.nan]
                except:
                    pass
                
            if count == dict():
                break
            else:
                most_common_value = count.most_common(1)[0][0]
                df.loc[df['categories'] == category, sub_df.columns[i]].fillna(most_common_value, 
                                                                               inplace=True)
# Out:
# 0 Amusement Parks, Event Planning & Services, Venues & Event Spaces, Community Service/Non-Profit, Local Services, Kids Activities, Active Life
# 1 Poutineries, Diners, Restaurants, Mediterranean
# 2 Waxing, Skin Care, Eyelash Service, Beauty & Spas, Hair Removal
# 3 Tanning, Skin Care, Nail Salons, Beauty & Spas
# 4 Restaurants, Mexican
# 5 Mini Golf, Hiking, Amateur Sports Teams, Active Life, Dog Parks, Parks, Playgrounds
# 6 Wedding Planning, Event Planning & Services, Officiants, Wedding Chapels
# 7 Wine Bars, Beer, Wine & Spirits, Restaurants, Mediterranean, Nightlife, Gluten-Free, Bars, Food, American (New), Breakfast & Brunch, Gastropubs, Burgers
# 8 Electronics, Drugstores, Discount Store, Grocery, Department Stores, Shopping, Fashion, Food
# 9 Pressure Washers, Roofing, Home Services, Painters
# 10 Italian, Kosher, Restaurants, Cafes, Middle Eastern, Food, Salad, Juice Bars & Smoothies, Coffee & Tea, Breakfast & Brunch, Pizza, Modern European
# 11 Desserts, Italian, Food, Pizza, Restaurants
# 12 Restaurants, American (New), Sandwiches, Salad, Soup
# 13 Active Life, Event Planning & Services, Venues & Event Spaces, Nightlife, Bowling
# 14 Movers, Packing Supplies, Accountants, Professional Services, Shopping, Home Services
# 15 Mini Golf, Active Life
# 16 Sandwiches, Chicken Wings, Burgers, Pizza, Food, Italian, Restaurants, Food Delivery Services
# 17 Bakeries, Restaurants, Fast Food, Ice Cream & Frozen Yogurt, Food
# 18 Desserts, Breakfast & Brunch, Restaurants, Indian, Food
# 19 Chinese, Restaurants, Szechuan, Asian Fusion, Seafood
# 20 Home Services, Tree Services, Irrigation, Nurseries & Gardening, Landscaping, Home & Garden, Shopping
# 21 Desserts, Food, Bakeries, Restaurants, Cafes
# 22 Beauty & Spas, Massage, Skin Care, Nail Salons, Day Spas
# 23 Fashion, Sports Wear, Shoe Stores, Shopping, Sporting Goods
# 24 Hair Removal, Beauty & Spas, Professional Services
# 25 Local Services, Carpet Cleaning, Home Cleaning, Tiling, Grout Services, Home Services
# 26 Noodles, Soup, Ramen, Restaurants, Japanese
# 27 Pizza, Food, Restaurants, Grocery
# 28 Pharmacy, Drugstores, Health & Medical, Shopping
# 29 Books, Mags, Music & Video, Automotive, Shopping, Auto Parts & Supplies, Bookstores
# 30 Sushi Bars, Ethnic Food, Kosher, Restaurants, Food, Specialty Food, Imported Food
# 31 Oral Surgeons, Health & Medical, General Dentistry, Dentists, Cosmetic Dentists
# 32 Egyptian, Middle Eastern, Mediterranean, Restaurants
# 33 Hotels, Professional Services, Venues & Event Spaces, Hotels & Travel, Resorts, Event Planning & Services
# 34 Hotels & Travel, Arts & Entertainment, Hotels, Event Planning & Services, Resorts, Casinos
# 35 Restaurants, Indonesian, Nightlife, Bars
# 36 Japanese, Teppanyaki, Sushi Bars, Restaurants
# 37 Event Planning & Services, Women's Clothing, Men's Clothing, Used, Vintage & Consignment, Shopping, Accessories, Bridal, Fashion, Wedding Planning
# 38 Restaurants, Kosher, Salad, Sandwiches
# 39 Health & Medical, Doctors, Pain Management, Anesthesiologists
# 40 Orthopedists, Doctors, Sports Medicine, Weight Loss Centers, Health & Medical
# 41 Eyelash Service, Waxing, Health & Medical, Medical Spas, Hair Salons, Hair Removal, Beauty & Spas, Skin Care
# 42 Health & Medical, General Dentistry, Dentists, Orthodontists, Endodontists
# 43 Active Life, Shopping, Food, Specialty Food, Gyms, Fitness & Instruction, Health Markets
# 44 Videographers, Session Photography, Event Planning & Services, Event Photography, Photographers
# 45 Restaurants, Seafood, Sushi Bars, Japanese
# 46 Fences & Gates, Contractors, Home Services, Local Services, Metal Fabricators, Door Sales/Installation
# 47 Nail Salons, Beauty & Spas, Massage, Cosmetics & Beauty Supply, Hair Salons, Shopping
# 48 Juice Bars & Smoothies, Specialty Food, Food, Fruits & Veggies
# 49 Bars, Restaurants, Food, Steakhouses, Seafood, Desserts, American (Traditional), Nightlife
# 50 Fashion, Used, Vintage & Consignment, Thrift Stores, Shopping
# 51 American (Traditional), Caterers, Nightlife, Restaurants, American (New), Party & Event Planning, Event Planning & Services
# 52 Automotive, Auto Repair, Towing, Oil Change Stations
# 53 American (New), Nightlife, Restaurants, Bars, Canadian (New), Pubs
# 54 Caribbean, Soul Food, Restaurants, Seafood
# 55 Venues & Event Spaces, Event Planning & Services, Bars, Nightlife, Dance Clubs
# 56 Persian/Iranian, Food, Caterers, Restaurants, Middle Eastern, Event Planning & Services
# 57 Nightlife, American (New), Sports Bars, Restaurants, American (Traditional), Bowling, Active Life, Bars
# 58 Restaurants, Irish, Nightlife, Arts & Entertainment, Food, Music Venues, Gastropubs, Beer, Wine & Spirits, Canadian (New), Bars
# 59 Diners, Vegetarian, Restaurants, Vegan
# 60 Hospitals, Restaurants, Health & Medical
# 61 Specialty Food, Barbeque, Food, Smokehouse, Restaurants
# 62 Contractors, Painters, Home Services
# 63 Health & Medical, Fertility, Doctors, Urologists
# 64 Home Services, Public Services & Government, Local Services, Professional Services, Mailbox Centers, Shipping Centers, Packing Services
# 137 General Dentistry, Oral Surgeons, Cosmetic Dentists, Health & Medical, Periodontists, Dentists
# 138 Emergency Pet Hospital, Pets, Veterinarians, Pet Services
# 139 Korean, Sushi Bars, Restaurants
# 140 Fruits & Veggies, Grocery, Specialty Food, Food, Farmers Market, Cheese Shops
# 141 Home Services, Real Estate, Commercial Real Estate, Shared Office Spaces
# 142 Coffee & Tea, Food, Tabletop Games, Chinese, Social Clubs, Cafes, Arts & Entertainment, Shopping, Restaurants
# 143 Shopping, Jewelry, Arts & Crafts
# 144 Dance Studios, Fitness & Instruction, Barre Classes, Active Life, Gyms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-0f242eb93582> in <module>
#      22             else:
#      23                 most_common_value = count.most_common(1)[0][0]
# ---> 24                 df.loc[df['categories'] == category, sub_df.columns[i]].fillna(most_common_value,
#      25                                                                                inplace=True)
#      26
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# KeyboardInterrupt:

# %%
nb = len(df)
NAs = dict()
for i in range(len(df.columns)):
    NAs[df.columns[i]] = sum(pd.isna(df[df.columns[i]]))*100/nb
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NAs[key]))

# %%
df.to_csv('../data/yelp_data.tsv', header=True, index=False)

# %% [markdown]
# # Appendix

# %% [markdown]
# # Train Validation Test Split

# %%
def dataset_split(proba, train, val):
    if proba < train:
        return 'train'
    elif proba < train + val:
        return 'validation'
    else:
        return 'test'

# %%
np.random.seed(42)

# %%
nb_users = len(user_df)
user_df['user_dataset'] = np.random.random(size=nb_users)
user_df['user_dataset'] = list(map(lambda p: dataset_split(p, 0.6, 0.2), user_df['user_dataset']))

# %%
nb_business = len(business_df)
business_df['business_dataset'] = np.random.random(size=nb_business)
business_df['business_dataset'] = list(map(lambda p: dataset_split(p, 0.6, 0.2), business_df['business_dataset']))

# %%
df['dataset'] = df['user_dataset'] == df['business_dataset']

# %%
df['dataset'] = df['user_dataset'] * list(map(int, df['dataset']))

# %%
df = df[df['dataset'] != '']
df.head()
# Out:
#                  review_id             business_id                 user_id  \
# 0   qVBtM3H5xFUMweX1qGsOnA  039QG6ks4UYNkMA3mcII2A  sThIuQa4EE8WocfxVFWMlA
# 3   32afZohbF1u3y7MeiusVHg  039QG6ks4UYNkMA3mcII2A  LHKSDD_2JJrsP5LyklZBJQ
# 6   EHBzcIp3HRNMzCsrRQmVlw  039QG6ks4UYNkMA3mcII2A  NsHeN5dKRmYfJTmTxMITmQ
# 10  MyHcKIdPm8utBElSIwB-Dw  039QG6ks4UYNkMA3mcII2A  51F0hQKX8I4bdJFiovcC4A
# 18  wynw5xnlkc74SuZJwrGOng  039QG6ks4UYNkMA3mcII2A  PnP3VHtR3SZTdKC_TgrVag
#
#     label  average_stars  compliment_cool  compliment_funny  compliment_note  \
# 0       1           4.68                1                 1                0
# 3       1           5.00                1                 1                1
# 6       1           3.90              103               103               44
# 10      1           4.58                1                 1                0
# 18      0           3.50                1                 1                0
#
#     compliment_plain  cool  ...  RestaurantsCounterService    Monday  \
# 0                  0    10  ...                        NaN  9:0-19:0
# 3                  1     2  ...                        NaN  9:0-19:0
# 6                 32   764  ...                        NaN  9:0-19:0
# 10                 0     7  ...                        NaN  9:0-19:0
# 18                 0     9  ...                        NaN  9:0-19:0
#
#      Tuesday  Wednesday  Thursday    Friday  Saturday     Sunday  \
# 0   9:0-19:0   9:0-19:0  9:0-19:0  9:0-19:0  9:0-19:0  10:0-16:0
# 3   9:0-19:0   9:0-19:0  9:0-19:0  9:0-19:0  9:0-19:0  10:0-16:0
# 6   9:0-19:0   9:0-19:0  9:0-19:0  9:0-19:0  9:0-19:0  10:0-16:0
# 10  9:0-19:0   9:0-19:0  9:0-19:0  9:0-19:0  9:0-19:0  10:0-16:0
# 18  9:0-19:0   9:0-19:0  9:0-19:0  9:0-19:0  9:0-19:0  10:0-16:0
#
#    business_dataset     dataset
# 0        validation  validation
# 3        validation  validation
# 6        validation  validation
# 10       validation  validation
# 18       validation  validation
#
# [5 rows x 125 columns]

# %%
print('='*80)
print('RAW REVIEWS DATASET DESCRIPTION')
nb_reviews = len(review_df)
pos_reviews = sum(review_df['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,d}'.format(nb_reviews))
print('Positive reviews: {:,d} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,d} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print('='*80)

print('REVIEWS DATASET AFTER SPLIT DESCRIPTION')
nb_reviews = len(df)
pos_reviews = sum(df['label'])
neg_revews = nb_reviews - pos_reviews
train_reviews = len(df[df['dataset'] == 'train'])
validation_reviews = len(df[df['dataset'] == 'validation'])
test_reviews = len(df[df['dataset'] == 'test'])

print('Total reviews: {:,d} - {:.2f}% of total reviews'.format(nb_reviews, 100*nb_reviews/len(review_df)))
print('Positive reviews: {:,d} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,d} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print()
print('Train reviews: {:,d} ({:.2f}%)'.format(train_reviews, 100*train_reviews/nb_reviews))
print('Validation reviews: {:,d} ({:.2f}%)'.format(validation_reviews, 100*validation_reviews/nb_reviews))
print('Test reviews: {:,d} ({:.2f}%)'.format(test_reviews, 100*test_reviews/nb_reviews))
print('='*80)

print('TRAIN REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df[df['dataset'] == 'train'])
pos_reviews = sum(df[df['dataset'] == 'train']['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,d}'.format(nb_reviews))
print('Positive reviews: {:,d} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,d} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print('='*80)

print('VALIDATION REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df[df['dataset'] == 'validation'])
pos_reviews = sum(df[df['dataset'] == 'validation']['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,d}'.format(nb_reviews))
print('Positive reviews: {:,d} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,d} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
print('='*80)

print('TEST REVIEWS DATASET DESCRIPTION')
nb_reviews = len(df[df['dataset'] == 'test'])
pos_reviews = sum(df[df['dataset'] == 'test']['label'])
neg_revews = nb_reviews - pos_reviews

print('Total reviews: {:,d}'.format(nb_reviews))
print('Positive reviews: {:,d} ({:.2f}%)'.format(pos_reviews, 100*pos_reviews/nb_reviews))
print('Negative reviews: {:,d} ({:.2f}%)'.format(neg_revews, 100*neg_revews/nb_reviews))
# Out:
# ================================================================================
# RAW REVIEWS DATASET DESCRIPTION
# Total reviews: 6,684,885
# Positive reviews: 2,932,663 (43.87%)
# Negative reviews: 3,752,222 (56.13%)
# ================================================================================
# REVIEWS DATASET AFTER SPLIT DESCRIPTION
# Total reviews: 2,554,927 - 38.22% of total reviews
# Positive reviews: 1,128,593 (44.17%)
# Negative reviews: 1,426,334 (55.83%)
#
# Train reviews: 2,088,015 (81.73%)
# Validation reviews: 237,404 (9.29%)
# Test reviews: 229,508 (8.98%)
# ================================================================================
# TRAIN REVIEWS DATASET DESCRIPTION
# Total reviews: 2,088,015
# Positive reviews: 920,414 (44.08%)
# Negative reviews: 1,167,601 (55.92%)
# ================================================================================
# VALIDATION REVIEWS DATASET DESCRIPTION
# Total reviews: 237,404
# Positive reviews: 105,342 (44.37%)
# Negative reviews: 132,062 (55.63%)
# ================================================================================
# TEST REVIEWS DATASET DESCRIPTION
# Total reviews: 229,508
# Positive reviews: 102,837 (44.81%)
# Negative reviews: 126,671 (55.19%)

# %%
NAs = dict()
n = len(df)
for i in range(len(df.columns)):
    NAs[df.columns[i]] = sum(pd.isna(df[df.columns[i]]))*100/n
    
for key in sorted(NAs, key=NAs.get, reverse=True):
    print('NA for {:35s}: {:.6f}%'.format(key, NAs[key]))
# Out:
# NA for BestNights                         : 99.993542%
# NA for HairSpecializesIn                  : 99.988728%
# NA for DietaryRestrictions                : 99.987514%
# NA for GoodForMeal                        : 99.942034%
# NA for DietaryRestrictions_dairy-free     : 99.842344%
# NA for DietaryRestrictions_gluten-free    : 99.842344%
# NA for DietaryRestrictions_vegan          : 99.842344%
# NA for DietaryRestrictions_kosher         : 99.842344%
# NA for DietaryRestrictions_halal          : 99.842344%
# NA for DietaryRestrictions_soy-free       : 99.842344%
# NA for DietaryRestrictions_vegetarian     : 99.842344%
# NA for Ambience                           : 99.841600%
# NA for Open24Hours                        : 99.840739%
# NA for RestaurantsCounterService          : 99.818234%
# NA for HairSpecializesIn_straightperms    : 99.682065%
# NA for HairSpecializesIn_africanamerican  : 99.682065%
# NA for HairSpecializesIn_asian            : 99.682065%
# NA for BYOB                               : 99.653924%
# NA for HairSpecializesIn_coloring         : 99.650401%
# NA for HairSpecializesIn_extensions       : 99.650401%
# NA for HairSpecializesIn_curly            : 99.650401%
# NA for HairSpecializesIn_kids             : 99.650401%
# NA for HairSpecializesIn_perms            : 99.650401%
# NA for Music                              : 99.643317%
# NA for AgesAllowed                        : 99.533176%
# NA for BusinessParking                    : 99.288629%
# NA for AcceptsInsurance                   : 97.851876%
# NA for Corkage                            : 96.060592%
# NA for DriveThru                          : 94.972068%
# NA for BYOBCorkage                        : 92.745938%
# NA for CoatCheck                          : 92.020320%
# NA for Smoking                            : 91.965798%
# NA for HappyHour                          : 89.211199%
# NA for Music_no_music                     : 89.140903%
# NA for DogsAllowed                        : 88.870876%
# NA for Music_background_music             : 88.448789%
# NA for Music_video                        : 88.446089%
# NA for Music_karaoke                      : 88.436578%
# NA for BestNights_monday                  : 88.436108%
# NA for BestNights_tuesday                 : 88.436108%
# NA for BestNights_friday                  : 88.436108%
# NA for BestNights_wednesday               : 88.436108%
# NA for BestNights_thursday                : 88.436108%
# NA for BestNights_sunday                  : 88.436108%
# NA for BestNights_saturday                : 88.436108%
# NA for Music_jukebox                      : 88.406401%
# NA for Music_live                         : 88.358024%
# NA for GoodForDancing                     : 88.053005%
# NA for Music_dj                           : 87.112978%
# NA for BusinessAcceptsBitcoin             : 85.460837%
# NA for ByAppointmentOnly                  : 83.548962%
# NA for WheelchairAccessible               : 77.041066%
# NA for RestaurantsTableService            : 68.402228%
# NA for GoodForMeal_dessert                : 42.967138%
# NA for GoodForMeal_latenight              : 42.967138%
# NA for GoodForMeal_lunch                  : 42.967138%
# NA for GoodForMeal_dinner                 : 42.967138%
# NA for GoodForMeal_breakfast              : 42.967138%
# NA for GoodForMeal_brunch                 : 42.966785%
# NA for Ambience_divey                     : 36.771462%
# NA for RestaurantsAttire                  : 35.178892%
# NA for NoiseLevel                         : 34.583610%
# NA for Caters                             : 34.488109%
# NA for Ambience_hipster                   : 33.265295%
# NA for Ambience_upscale                   : 33.226077%
# NA for Ambience_romantic                  : 33.193943%
# NA for Ambience_intimate                  : 33.193943%
# NA for Ambience_classy                    : 33.193943%
# NA for Ambience_touristy                  : 33.193943%
# NA for Ambience_trendy                    : 33.193943%
# NA for Ambience_casual                    : 33.193943%
# NA for HasTV                              : 33.095544%
# NA for RestaurantsReservations            : 33.068381%
# NA for RestaurantsDelivery                : 32.933152%
# NA for Alcohol                            : 32.155909%
# NA for RestaurantsGoodForGroups           : 31.794764%
# NA for OutdoorSeating                     : 30.337853%
# NA for WiFi                               : 29.098835%
# NA for RestaurantsTakeOut                 : 29.037620%
# NA for GoodForKids                        : 27.534877%
# NA for BikeParking                        : 18.073550%
# NA for Sunday                             : 16.601022%
# NA for BusinessAcceptsCreditCards         : 15.707729%
# NA for BusinessParking_validated          : 14.593176%
# NA for BusinessParking_street             : 14.592981%
# NA for BusinessParking_lot                : 14.592981%
# NA for BusinessParking_valet              : 14.592824%
# NA for BusinessParking_garage             : 14.591219%
# NA for RestaurantsPriceRange2             : 12.856297%
# NA for Monday                             : 6.580540%
# NA for Saturday                           : 4.152604%
# NA for Tuesday                            : 2.615809%
# NA for Wednesday                          : 1.385519%
# NA for Thursday                           : 0.825033%
# NA for Friday                             : 0.625497%
# NA for review_id                          : 0.000000%
# NA for business_id                        : 0.000000%
# NA for user_id                            : 0.000000%
# NA for label                              : 0.000000%
# NA for average_stars                      : 0.000000%
# NA for compliment_cool                    : 0.000000%
# NA for compliment_funny                   : 0.000000%
# NA for compliment_note                    : 0.000000%
# NA for compliment_plain                   : 0.000000%
# NA for cool                               : 0.000000%
# NA for fans                               : 0.000000%
# NA for funny                              : 0.000000%
# NA for review_count_x                     : 0.000000%
# NA for useful                             : 0.000000%
# NA for seniority                          : 0.000000%
# NA for nb_friends                         : 0.000000%
# NA for user_dataset                       : 0.000000%
# NA for address                            : 0.000000%
# NA for categories                         : 0.000000%
# NA for city                               : 0.000000%
# NA for is_open                            : 0.000000%
# NA for latitude                           : 0.000000%
# NA for longitude                          : 0.000000%
# NA for name                               : 0.000000%
# NA for postal_code                        : 0.000000%
# NA for review_count_y                     : 0.000000%
# NA for stars                              : 0.000000%
# NA for state                              : 0.000000%
# NA for business_dataset                   : 0.000000%
# NA for dataset                            : 0.000000%
